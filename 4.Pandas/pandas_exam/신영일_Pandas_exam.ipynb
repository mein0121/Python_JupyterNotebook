# %% [markdown]
# # Seoul_report.csv 읽기
# + 서울시 주민등록인구 (구별) 통계 - [서울열린데이터광장 ](http://data.seoul.go.kr/dataList/datasetView.do?serviceKind=2&infId=419&stcSrl=419&srvType=S)

# %% [markdown]
# ## CSV 파일 읽기
# - Seoul_report.csv 파일의 내용을 DataFrame으로 읽고 변수에 대입

# %%
import numpy as np
import pandas as pd
s_report = pd.read_csv('Seoul_report.csv')
s_report
# Out:
#      자치구       세대       총합계       남자       여자    한국인합계    한국인남자    한국인여자  \
# 0     합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 1    종로구    73879    164348    79962    84386   154549    75749    78800
# 2     중구    60903    135139    66582    68557   126082    62376    63706
# 3    용산구   108497    245411   119985   125426   229909   111262   118647
# 4    성동구   134543    314551   154672   159879   306532   150937   155595
# 5    광진구   161407    371671   180206   191465   357149   173946   183203
# 6   동대문구   160489    364962   180381   184581   349308   174476   174832
# 7    중랑구   179600    411552   204411   207141   406868   202526   204342
# 8    성북구   187234    453902   220024   233878   442226   215421   226805
# 9    강북구   143139    327511   159853   167658   323862   158440   165422
# 10   도봉구   137479    345041   168833   176208   342861   168009   174852
# 11   노원구   217999    555803   269762   286041   551902   268144   283758
# ...

# %% [markdown]
# # 열명 변경
# - 읽은 DataFrame에 어떤 컬럼이 있는지 확인하고 열명을 아래와 같이 바꾼다. (이외 열이름은 그대로 유지)
#     - '총합계' : '총인구'
#     - '한국인합계': '한국인'
#     - '외국인합계' : '외국인'
#     - '65세이상고령자' : '고령자'

# %%
s_report.columns
# Out:
# Index(['자치구', '세대', '총합계', '남자', '여자', '한국인합계', '한국인남자', '한국인여자', '외국인합계',
#        '남자외국인', '여자외국인', '세대당인구', '65세이상고령자'],
#       dtype='object')

# %%
#s1.columns=[] # 전체 컬럼명 변경.
#일부 컬럼 변경시 :rename({"기존이름:"새이름",....}, axis=1)
mp = {'총합계' : '총인구',
'한국인합계': '한국인',
'외국인합계' : '외국인',
'65세이상고령자' : '고령자'}
s1 = s_report.rename(mp, axis=1)
s1
# Out:
#      자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 0     합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 1    종로구    73879    164348    79962    84386   154549    75749    78800
# 2     중구    60903    135139    66582    68557   126082    62376    63706
# 3    용산구   108497    245411   119985   125426   229909   111262   118647
# 4    성동구   134543    314551   154672   159879   306532   150937   155595
# 5    광진구   161407    371671   180206   191465   357149   173946   183203
# 6   동대문구   160489    364962   180381   184581   349308   174476   174832
# 7    중랑구   179600    411552   204411   207141   406868   202526   204342
# 8    성북구   187234    453902   220024   233878   442226   215421   226805
# 9    강북구   143139    327511   159853   167658   323862   158440   165422
# 10   도봉구   137479    345041   168833   176208   342861   168009   174852
# 11   노원구   217999    555803   269762   286041   551902   268144   283758
# ...

# %% [markdown]
# # 사용할 열들만 추출
# - 자치구, 총인구, 한국인, 외국인, 고령자 열만 가지는 dataframe 생성
#     - shape이 (5, n) 이 되도록

# %%
s2 = s1[['자치구', '총인구', '한국인', '외국인', '고령자']]

# %%
s2
# Out:
#      자치구       총인구      한국인     외국인      고령자
# 0     합계  10112070  9838892  273178  1382420
# 1    종로구    164348   154549    9799    26429
# 2     중구    135139   126082    9057    21655
# 3    용산구    245411   229909   15502    37238
# 4    성동구    314551   306532    8019    41752
# 5    광진구    371671   357149   14522    44470
# 6   동대문구    364962   349308   15654    56284
# 7    중랑구    411552   406868    4684    59992
# 8    성북구    453902   442226   11676    66896
# 9    강북구    327511   323862    3649    57002
# 10   도봉구    345041   342861    2180    54293
# 11   노원구    555803   551902    3901    75081
# 12   은평구    490253   485902    4351    75535
# 13  서대문구    324871   312311   12560    49645
# 14   마포구    385624   374742   10882    50122
# 15   양천구    473087   469221    3866    56070
# 16   강서구    608361   601696    6665    77381
# 17   구로구    440396   408369   32027    59838
# 18   금천구    253344   234238   19106    34640
# 19  영등포구    403988   369128   34860    54704
# ...

# %%
s5 = s1.filter(items=['자치구', '총인구', '한국인', '외국인', '고령자']).T
s5, s5.shape
# Out:
# (           0       1       2       3       4       5       6       7       8   \
#  자치구        합계     종로구      중구     용산구     성동구     광진구    동대문구     중랑구     성북구
#  총인구  10112070  164348  135139  245411  314551  371671  364962  411552  453902
#  한국인   9838892  154549  126082  229909  306532  357149  349308  406868  442226
#  외국인    273178    9799    9057   15502    8019   14522   15654    4684   11676
#  고령자   1382420   26429   21655   37238   41752   44470   56284   59992   66896
#
#           9   ...      16      17      18      19      20      21      22  \
#  자치구     강북구  ...     강서구     구로구     금천구    영등포구     동작구     관악구     서초구
#  총인구  327511  ...  608361  440396  253344  403988  406715  522292  445164
#  한국인  323862  ...  601696  408369  234238  369128  394353  504445  440954
#  외국인    3649  ...    6665   32027   19106   34860   12362   17847    4210
#  고령자   57002  ...   77381   59838   34640   54704   57711   70807   54055
#
#           23      24      25
# ...

# %% [markdown]
# # DataFrame 개괄 정보 조회
# 1. 몇행/몇열인지 조회
# 1. 결측치가 있는지 조회
# 1. DataFrame에 대한 정보(index, columns) 확인
# 1. 상위 5개 행만 조회
# 1. 하위 5개 행만 조회
# 1. 컬럼별 통계량 요약 조회

# %%
s1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     26 non-null     object
#  1   세대      26 non-null     int64
#  2   총인구     26 non-null     int64
#  3   남자      26 non-null     int64
#  4   여자      26 non-null     int64
#  5   한국인     26 non-null     int64
#  6   한국인남자   26 non-null     int64
#  7   한국인여자   26 non-null     int64
#  8   외국인     26 non-null     int64
#  9   남자외국인   26 non-null     int64
#  10  여자외국인   26 non-null     int64
#  11  세대당인구   26 non-null     float64
#  12  고령자     26 non-null     int64
# dtypes: float64(1), int64(11), object(1)
# memory usage: 2.8+ KB

# %%
s1.shape
# Out:
# (26, 13)

# %%
s1.isnull()
s1.isnull().sum()
# Out:
# 자치구      0
# 세대       0
# 총인구      0
# 남자       0
# 여자       0
# 한국인      0
# 한국인남자    0
# 한국인여자    0
# 외국인      0
# 남자외국인    0
# 여자외국인    0
# 세대당인구    0
# 고령자      0
# dtype: int64

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=26, step=1)

# %%
s1.columns
# Out:
# Index(['자치구', '세대', '총인구', '남자', '여자', '한국인', '한국인남자', '한국인여자', '외국인', '남자외국인',
#        '여자외국인', '세대당인구', '고령자'],
#       dtype='object')

# %%
상위 5개 행만 조회
하위 5개 행만 조회
컬럼별 통계량 요약 조회

# %%
s1.head()
# Out:
#    자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 0   합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 1  종로구    73879    164348    79962    84386   154549    75749    78800
# 2   중구    60903    135139    66582    68557   126082    62376    63706
# 3  용산구   108497    245411   119985   125426   229909   111262   118647
# 4  성동구   134543    314551   154672   159879   306532   150937   155595
#
#       외국인   남자외국인   여자외국인  세대당인구      고령자
# 0  273178  130974  142204   2.32  1382420
# 1    9799    4213    5586   2.09    26429
# 2    9057    4206    4851   2.07    21655
# 3   15502    8723    6779   2.12    37238
# 4    8019    3735    4284   2.28    41752

# %%
s1.tail()
# Out:
#     자치구      세대     총인구      남자      여자     한국인   한국인남자   한국인여자    외국인  남자외국인  \
# 21  관악구  258536  522292  262428  259864  504445  253911  250534  17847   8517
# 22  서초구  174225  445164  213279  231885  440954  211156  229798   4210   2123
# 23  강남구  231219  557865  267314  290551  552976  264834  288142   4889   2480
# 24  송파구  266550  671994  326511  345483  665282  323228  342054   6712   3283
# 25  강동구  177490  438225  217570  220655  434027  215588  218439   4198   1982
#
#     여자외국인  세대당인구    고령자
# 21   9330   1.95  70807
# 22   2087   2.53  54055
# 23   2409   2.39  65859
# 24   3429   2.50  77978
# 25   2216   2.45  56983

# %%
s2.describe()
# Out:
#                 총인구           한국인            외국인           고령자
# count  2.600000e+01  2.600000e+01      26.000000  2.600000e+01
# mean   7.778515e+05  7.568378e+05   21013.692308  1.063400e+05
# std    1.907984e+06  1.856777e+06   52081.287523  2.606869e+05
# min    1.351390e+05  1.260820e+05    2180.000000  2.165500e+04
# 25%    3.318935e+05  3.286118e+05    4434.250000  4.976425e+04
# 50%    4.091335e+05  4.006105e+05    9428.000000  5.663350e+04
# 75%    4.859615e+05  4.817318e+05   15257.000000  6.663675e+04
# max    1.011207e+07  9.838892e+06  273178.000000  1.382420e+06

# %% [markdown]
# # 열이름으로 조회
# 1. 총인구 열의 모든 값들을 조회
# 1. 한국인, 외국인 열의 모든 값들을 조회

# %%
s2['총인구']
s1.총인구
# Out:
# 0     10112070
# 1       164348
# 2       135139
# 3       245411
# 4       314551
# 5       371671
# 6       364962
# 7       411552
# 8       453902
# 9       327511
# 10      345041
# 11      555803
# 12      490253
# 13      324871
# 14      385624
# 15      473087
# 16      608361
# 17      440396
# 18      253344
# 19      403988
# 20      406715
# 21      522292
# 22      445164
# 23      557865
# 24      671994
# 25      438225
# Name: 총인구, dtype: int64

# %%
s1[['한국인','외국인']]
# Out:
#         한국인     외국인
# 0   9838892  273178
# 1    154549    9799
# 2    126082    9057
# 3    229909   15502
# 4    306532    8019
# 5    357149   14522
# 6    349308   15654
# 7    406868    4684
# 8    442226   11676
# 9    323862    3649
# 10   342861    2180
# 11   551902    3901
# 12   485902    4351
# 13   312311   12560
# 14   374742   10882
# 15   469221    3866
# 16   601696    6665
# 17   408369   32027
# 18   234238   19106
# 19   369128   34860
# 20   394353   12362
# 21   504445   17847
# 22   440954    4210
# 23   552976    4889
# 24   665282    6712
# 25   434027    4198

# %%
s1.loc[:,['한국인','외국인']]
# Out:
#         한국인     외국인
# 0   9838892  273178
# 1    154549    9799
# 2    126082    9057
# 3    229909   15502
# 4    306532    8019
# 5    357149   14522
# 6    349308   15654
# 7    406868    4684
# 8    442226   11676
# 9    323862    3649
# 10   342861    2180
# 11   551902    3901
# 12   485902    4351
# 13   312311   12560
# 14   374742   10882
# 15   469221    3866
# 16   601696    6665
# 17   408369   32027
# 18   234238   19106
# 19   369128   34860
# 20   394353   12362
# 21   504445   17847
# 22   440954    4210
# 23   552976    4889
# 24   665282    6712
# 25   434027    4198

# %%
s1.iloc[:,[5,8]]
# Out:
#         한국인     외국인
# 0   9838892  273178
# 1    154549    9799
# 2    126082    9057
# 3    229909   15502
# 4    306532    8019
# 5    357149   14522
# 6    349308   15654
# 7    406868    4684
# 8    442226   11676
# 9    323862    3649
# 10   342861    2180
# 11   551902    3901
# 12   485902    4351
# 13   312311   12560
# 14   374742   10882
# 15   469221    3866
# 16   601696    6665
# 17   408369   32027
# 18   234238   19106
# 19   369128   34860
# 20   394353   12362
# 21   504445   17847
# 22   440954    4210
# 23   552976    4889
# 24   665282    6712
# 25   434027    4198

# %% [markdown]
# # 행기준 조회
# 1. 5번째 행의 데이터를 조회.
# 1. 1, 5, 7, 10 번째 행의 데이터를 조회
# 1. 15 ~ 20 번째 행의 데이터를 조회
# 1. 10~15 행에서 자치구, 총인구, 한국인 열의 값을 조회
# 1. 6, 7, 8 번째 행의 한국인, 외국인 열의 값을 조회

# %%
s1.iloc[[4]]
# Out:
#    자치구      세대     총인구      남자      여자     한국인   한국인남자   한국인여자   외국인  남자외국인  \
# 4  성동구  134543  314551  154672  159879  306532  150937  155595  8019   3735
#
#    여자외국인  세대당인구    고령자
# 4   4284   2.28  41752

# %%
s1.iloc[[0,4,6,9]]
# Out:
#     자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 0    합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 4   성동구   134543    314551   154672   159879   306532   150937   155595
# 6  동대문구   160489    364962   180381   184581   349308   174476   174832
# 9   강북구   143139    327511   159853   167658   323862   158440   165422
#
#       외국인   남자외국인   여자외국인  세대당인구      고령자
# 0  273178  130974  142204   2.32  1382420
# 4    8019    3735    4284   2.28    41752
# 6   15654    5905    9749   2.18    56284
# 9    3649    1413    2236   2.26    57002

# %%
s1.iloc[14:20]
# Out:
#      자치구      세대     총인구      남자      여자     한국인   한국인남자   한국인여자    외국인  \
# 14   마포구  170219  385624  182905  202719  374742  178661  196081  10882
# 15   양천구  176559  473087  233189  239898  469221  231409  237812   3866
# 16   강서구  256042  608361  296098  312263  601696  292871  308825   6665
# 17   구로구  171751  440396  220903  219493  408369  202731  205638  32027
# 18   금천구  106333  253344  129791  123553  234238  119023  115215  19106
# 19  영등포구  168784  403988  203472  200516  369128  184127  185001  34860
#
#     남자외국인  여자외국인  세대당인구    고령자
# 14   4244   6638   2.20  50122
# 15   1780   2086   2.66  56070
# 16   3227   3438   2.35  77381
# 17  18172  13855   2.38  59838
# 18  10768   8338   2.20  34640
# 19  19345  15515   2.19  54704

# %%
s1.loc[10:15,['자치구', '총인구', '한국인']]
s1.iloc[10:15,[0,1,2]]
s2.iloc[10:15,0:3]
# Out:
#      자치구     총인구     한국인
# 10   도봉구  345041  342861
# 11   노원구  555803  551902
# 12   은평구  490253  485902
# 13  서대문구  324871  312311
# 14   마포구  385624  374742

# %%
6, 7, 8 번째 행의 한국인, 외국인 열의 값을 조회

# %%
s1.loc[6:8,['한국인','외국인']]
s2.iloc[[5,6,7],[2,3]]
# Out:
#       한국인    외국인
# 5  357149  14522
# 6  349308  15654
# 7  406868   4684

# %% [markdown]
# # index 이름 지정
# 1. '자치구' 열을 index로 설정
# 1. 데이터 프레임의 index이름 조회
# 1. 강남구 행 조회
# 1. 종로구, 성동구, 서대문구 행 조회
# 1. 노원구 ~ 금천구 조회
# 1. 종로구의 한국인,외국인 열의 값 조회
# 1. 도봉구, 노원구, 송파구의 총인구와 고령자 열의 값 조회

# %%
#s2.set_index('자치구', inplace=True)
s2 = s2.set_index('자치구')

# %%
s2.index
# Out:
# Index(['합계', '종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구',
#        '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype='object', name='자치구')

# %%
s2.head()
# Out:
#           총인구      한국인     외국인      고령자
# 자치구
# 합계   10112070  9838892  273178  1382420
# 종로구    164348   154549    9799    26429
# 중구     135139   126082    9057    21655
# 용산구    245411   229909   15502    37238
# 성동구    314551   306532    8019    41752

# %%
s2.loc[['강남구']]
# Out:
#          세대     총인구      남자      여자     한국인   한국인남자   한국인여자   외국인  남자외국인  \
# 자치구
# 강남구  231219  557865  267314  290551  552976  264834  288142  4889   2480
#
#      여자외국인  세대당인구    고령자
# 자치구
# 강남구   2409   2.39  65859

# %%
s2.loc[['종로구', '성동구', '서대문구']]
# Out:
#           세대     총인구      남자      여자     한국인   한국인남자   한국인여자    외국인  남자외국인  \
# 자치구
# 종로구    73879  164348   79962   84386  154549   75749   78800   9799   4213
# 성동구   134543  314551  154672  159879  306532  150937  155595   8019   3735
# 서대문구  137758  324871  154960  169911  312311  150793  161518  12560   4167
#
#       여자외국인  세대당인구    고령자
# 자치구
# 종로구    5586   2.09  26429
# 성동구    4284   2.28  41752
# 서대문구   8393   2.27  49645

# %%
노원구 ~ 금천구 조회
종로구의 한국인,외국인 열의 값 조회
도봉구, 노원구, 송파구의 총인구와 고령자 열의 값 조회

# %%
s2.loc['노원구':'금천구']
# Out:
#           세대     총인구      남자      여자     한국인   한국인남자   한국인여자    외국인  남자외국인  \
# 자치구
# 노원구   217999  555803  269762  286041  551902  268144  283758   3901   1618
# 은평구   203431  490253  237542  252711  485902  235674  250228   4351   1868
# 서대문구  137758  324871  154960  169911  312311  150793  161518  12560   4167
# 마포구   170219  385624  182905  202719  374742  178661  196081  10882   4244
# 양천구   176559  473087  233189  239898  469221  231409  237812   3866   1780
# 강서구   256042  608361  296098  312263  601696  292871  308825   6665   3227
# 구로구   171751  440396  220903  219493  408369  202731  205638  32027  18172
# 금천구   106333  253344  129791  123553  234238  119023  115215  19106  10768
#
#       여자외국인  세대당인구    고령자
# 자치구
# 노원구    2283   2.53  75081
# 은평구    2483   2.39  75535
# 서대문구   8393   2.27  49645
# 마포구    6638   2.20  50122
# 양천구    2086   2.66  56070
# 강서구    3438   2.35  77381
# 구로구   13855   2.38  59838
# 금천구    8338   2.20  34640

# %%
s2.loc['종로구',['한국인','외국인']]
# Out:
# 한국인    154549
# 외국인      9799
# Name: 종로구, dtype: int64

# %%
s2.loc[['도봉구', '노원구', '송파구'],['총인구','고령자']]
# Out:
#         총인구    고령자
# 자치구
# 도봉구  345041  54293
# 노원구  555803  75081
# 송파구  671994  77978

# %% [markdown]
# # Boolean 인덱싱 - 조건으로 조회
# 1. 총인구가 500,000 이상인 행 조회
# 1. 외국인이 15,000 이상인 행의 한국인, 외국인 열 조회
# 1. 외국인이 고령자보다 많은 행을 조회 (없으므로 아무 행도 안나오는게 정상임)
# 1. 고령자수가 60,000 ~ 70,000 인 행 조회
# 1. 외국인이 15,000 이상이고 고령자가 50,000 이상인 행을 조회

# %%
s2[s2['총인구']>=500000]
s2.loc[s2['총인구']>=500000]
# Out:
#           총인구      한국인     외국인      고령자
# 자치구
# 합계   10112070  9838892  273178  1382420
# 노원구    555803   551902    3901    75081
# 강서구    608361   601696    6665    77381
# 관악구    522292   504445   17847    70807
# 강남구    557865   552976    4889    65859
# 송파구    671994   665282    6712    77978

# %%
s2[s2['외국인']>=15000][['한국인','외국인']]
s2.loc[s2['외국인']>=15000,['한국인','외국인']]
# Out:
#           한국인     외국인
# 자치구
# 합계    9838892  273178
# 용산구    229909   15502
# 동대문구   349308   15654
# 구로구    408369   32027
# 금천구    234238   19106
# 영등포구   369128   34860
# 관악구    504445   17847

# %%
외국인이 고령자보다 많은 행을 조회 (없으므로 아무 행도 안나오는게 정상임)
고령자수가 60,000 ~ 70,000 인 행 조회
외국인이 15,000 이상이고 고령자가 50,000 이상인 행을 조회

# %%
s2[s2['외국인']>s2['고령자']]
s2.loc[s2['외국인']>s2['고령자']]
# Out:
# Empty DataFrame
# Columns: [총인구, 한국인, 외국인, 고령자]
# Index: []

# %%
s2[(s2['고령자']>=60000)&(s2['고령자']<=70000)]
s2.loc[(s2['고령자']>=60000)&(s2['고령자']<=70000)]
s2.loc[s2['고령자'].between(60000,70000)]
# Out:
#         총인구     한국인    외국인    고령자
# 자치구
# 성북구  453902  442226  11676  66896
# 강남구  557865  552976   4889  65859

# %%
s2.loc[(s2['외국인']>=15000) & (s2['고령자']>=50000)]
# Out:
#            총인구      한국인     외국인      고령자
# 자치구
# 합계    10112070  9838892  273178  1382420
# 동대문구    364962   349308   15654    56284
# 구로구     440396   408369   32027    59838
# 영등포구    403988   369128   34860    54704
# 관악구     522292   504445   17847    70807

# %% [markdown]
# # 정렬
# 1. 자치구컬럼 기준 오름차순 순으로 정렬
# 1. 자치구컬럼 기준 내림차순 순으로 정렬
# 1. 외국인이 많이 있는 순으로 정렬
# 1. 한국인이 많이 있는 순서로 정렬하고 혹시 같으면 고령자가 적은 순으로 2차 정렬
# 1. 합계를 지우고 총인구 내림차순으로 정렬

# %%
s3 = s2.sort_index(ascending=True)

# %%
s2.sort_index(ascending=True)
# Out:
#            총인구      한국인     외국인      고령자
# 자치구
# 강남구     557865   552976    4889    65859
# 강동구     438225   434027    4198    56983
# 강북구     327511   323862    3649    57002
# 강서구     608361   601696    6665    77381
# 관악구     522292   504445   17847    70807
# 광진구     371671   357149   14522    44470
# 구로구     440396   408369   32027    59838
# 금천구     253344   234238   19106    34640
# 노원구     555803   551902    3901    75081
# 도봉구     345041   342861    2180    54293
# 동대문구    364962   349308   15654    56284
# 동작구     406715   394353   12362    57711
# 마포구     385624   374742   10882    50122
# 서대문구    324871   312311   12560    49645
# 서초구     445164   440954    4210    54055
# 성동구     314551   306532    8019    41752
# 성북구     453902   442226   11676    66896
# 송파구     671994   665282    6712    77978
# 양천구     473087   469221    3866    56070
# 영등포구    403988   369128   34860    54704
# 용산구     245411   229909   15502    37238
# 은평구     490253   485902    4351    75535
# ...

# %%
s2.sort_index(axis=1) #컬럼기준 정렬
# Out:
#           고령자     외국인       총인구      한국인
# 자치구
# 합계    1382420  273178  10112070  9838892
# 종로구     26429    9799    164348   154549
# 중구      21655    9057    135139   126082
# 용산구     37238   15502    245411   229909
# 성동구     41752    8019    314551   306532
# 광진구     44470   14522    371671   357149
# 동대문구    56284   15654    364962   349308
# 중랑구     59992    4684    411552   406868
# 성북구     66896   11676    453902   442226
# 강북구     57002    3649    327511   323862
# 도봉구     54293    2180    345041   342861
# 노원구     75081    3901    555803   551902
# 은평구     75535    4351    490253   485902
# 서대문구    49645   12560    324871   312311
# 마포구     50122   10882    385624   374742
# 양천구     56070    3866    473087   469221
# 강서구     77381    6665    608361   601696
# 구로구     59838   32027    440396   408369
# 금천구     34640   19106    253344   234238
# 영등포구    54704   34860    403988   369128
# 동작구     57711   12362    406715   394353
# 관악구     70807   17847    522292   504445
# ...

# %%
s3['과':'도'] # 인덱스 오름차순 설정이되있을경우.
# Out:
#         총인구     한국인    외국인    고령자
# 자치구
# 관악구  522292  504445  17847  70807
# 광진구  371671  357149  14522  44470
# 구로구  440396  408369  32027  59838
# 금천구  253344  234238  19106  34640
# 노원구  555803  551902   3901  75081

# %%
s2.sort_index(ascending=False)
# Out:
#            총인구      한국인     외국인      고령자
# 자치구
# 합계    10112070  9838892  273178  1382420
# 중랑구     411552   406868    4684    59992
# 중구      135139   126082    9057    21655
# 종로구     164348   154549    9799    26429
# 은평구     490253   485902    4351    75535
# 용산구     245411   229909   15502    37238
# 영등포구    403988   369128   34860    54704
# 양천구     473087   469221    3866    56070
# 송파구     671994   665282    6712    77978
# 성북구     453902   442226   11676    66896
# 성동구     314551   306532    8019    41752
# 서초구     445164   440954    4210    54055
# 서대문구    324871   312311   12560    49645
# 마포구     385624   374742   10882    50122
# 동작구     406715   394353   12362    57711
# 동대문구    364962   349308   15654    56284
# 도봉구     345041   342861    2180    54293
# 노원구     555803   551902    3901    75081
# 금천구     253344   234238   19106    34640
# 구로구     440396   408369   32027    59838
# 광진구     371671   357149   14522    44470
# 관악구     522292   504445   17847    70807
# ...

# %%
s2.sort_values('외국인',ascending=False)
# Out:
#            총인구      한국인     외국인      고령자
# 자치구
# 합계    10112070  9838892  273178  1382420
# 영등포구    403988   369128   34860    54704
# 구로구     440396   408369   32027    59838
# 금천구     253344   234238   19106    34640
# 관악구     522292   504445   17847    70807
# 동대문구    364962   349308   15654    56284
# 용산구     245411   229909   15502    37238
# 광진구     371671   357149   14522    44470
# 서대문구    324871   312311   12560    49645
# 동작구     406715   394353   12362    57711
# 성북구     453902   442226   11676    66896
# 마포구     385624   374742   10882    50122
# 종로구     164348   154549    9799    26429
# 중구      135139   126082    9057    21655
# 성동구     314551   306532    8019    41752
# 송파구     671994   665282    6712    77978
# 강서구     608361   601696    6665    77381
# 강남구     557865   552976    4889    65859
# 중랑구     411552   406868    4684    59992
# 은평구     490253   485902    4351    75535
# 서초구     445164   440954    4210    54055
# 강동구     438225   434027    4198    56983
# ...

# %%
s2.sort_values(['한국인','고령자'],ascending=[False,True])
# Out:
#            세대       총인구       남자       여자      한국인    한국인남자    한국인여자     외국인  \
# 자치구
# 합계    4237610  10112070  4948481  5163589  9838892  4817507  5021385  273178
# 송파구    266550    671994   326511   345483   665282   323228   342054    6712
# 강서구    256042    608361   296098   312263   601696   292871   308825    6665
# 강남구    231219    557865   267314   290551   552976   264834   288142    4889
# 노원구    217999    555803   269762   286041   551902   268144   283758    3901
# 관악구    258536    522292   262428   259864   504445   253911   250534   17847
# 은평구    203431    490253   237542   252711   485902   235674   250228    4351
# 양천구    176559    473087   233189   239898   469221   231409   237812    3866
# 성북구    187234    453902   220024   233878   442226   215421   226805   11676
# 서초구    174225    445164   213279   231885   440954   211156   229798    4210
# 강동구    177490    438225   217570   220655   434027   215588   218439    4198
# ...

# %%
s3 = s2.drop(labels='합계').sort_values('총인구')
s3
# Out:
#          총인구     한국인    외국인    고령자
# 자치구
# 중구    135139  126082   9057  21655
# 종로구   164348  154549   9799  26429
# 용산구   245411  229909  15502  37238
# 금천구   253344  234238  19106  34640
# 성동구   314551  306532   8019  41752
# 서대문구  324871  312311  12560  49645
# 강북구   327511  323862   3649  57002
# 도봉구   345041  342861   2180  54293
# 동대문구  364962  349308  15654  56284
# 광진구   371671  357149  14522  44470
# 마포구   385624  374742  10882  50122
# 영등포구  403988  369128  34860  54704
# 동작구   406715  394353  12362  57711
# 중랑구   411552  406868   4684  59992
# 강동구   438225  434027   4198  56983
# 구로구   440396  408369  32027  59838
# 서초구   445164  440954   4210  54055
# 성북구   453902  442226  11676  66896
# 양천구   473087  469221   3866  56070
# 은평구   490253  485902   4351  75535
# 관악구   522292  504445  17847  70807
# 노원구   555803  551902   3901  75081
# 강남구   557865  552976   4889  65859
# 강서구   608361  601696   6665  77381
# 송파구   671994  665282   6712  77978

# %%
s3 = s2.drop(index='합계').sort_values('총인구', ascending=False)
s3
# Out:
#          총인구     한국인    외국인    고령자
# 자치구
# 송파구   671994  665282   6712  77978
# 강서구   608361  601696   6665  77381
# 강남구   557865  552976   4889  65859
# 노원구   555803  551902   3901  75081
# 관악구   522292  504445  17847  70807
# 은평구   490253  485902   4351  75535
# 양천구   473087  469221   3866  56070
# 성북구   453902  442226  11676  66896
# 서초구   445164  440954   4210  54055
# 구로구   440396  408369  32027  59838
# 강동구   438225  434027   4198  56983
# 중랑구   411552  406868   4684  59992
# 동작구   406715  394353  12362  57711
# 영등포구  403988  369128  34860  54704
# 마포구   385624  374742  10882  50122
# 광진구   371671  357149  14522  44470
# 동대문구  364962  349308  15654  56284
# 도봉구   345041  342861   2180  54293
# 강북구   327511  323862   3649  57002
# 서대문구  324871  312311  12560  49645
# 성동구   314551  306532   8019  41752
# 금천구   253344  234238  19106  34640
# 용산구   245411  229909  15502  37238
# 종로구   164348  154549   9799  26429
# 중구    135139  126082   9057  21655

# %% [markdown]
# # 열 추가 - 파생변수
# 1. 총인구 대비 외국인의 비율을 계산한 값을 **외국인비율** 컬럼을 만들어 넣기 (외국인/총인구 * 100)
# 1. 총인구 대비 고령자의 비율을 계산한 값을 **고령자비율** 컬럼을 만들어 넣기

# %%
#벡터화
import numpy as np
s3['외국인비율'] = np.round(df['외국인']/df['총인구']*100, 2)

# %%
s3['외국인비율'] = np.round((s3['외국인']/s3['총인구'])*100,2)
s3
# Out:
#          총인구     한국인    외국인    고령자  외국인비율
# 자치구
# 송파구   671994  665282   6712  77978   1.00
# 강서구   608361  601696   6665  77381   1.10
# 강남구   557865  552976   4889  65859   0.88
# 노원구   555803  551902   3901  75081   0.70
# 관악구   522292  504445  17847  70807   3.42
# 은평구   490253  485902   4351  75535   0.89
# 양천구   473087  469221   3866  56070   0.82
# 성북구   453902  442226  11676  66896   2.57
# 서초구   445164  440954   4210  54055   0.95
# 구로구   440396  408369  32027  59838   7.27
# 강동구   438225  434027   4198  56983   0.96
# 중랑구   411552  406868   4684  59992   1.14
# 동작구   406715  394353  12362  57711   3.04
# 영등포구  403988  369128  34860  54704   8.63
# 마포구   385624  374742  10882  50122   2.82
# 광진구   371671  357149  14522  44470   3.91
# 동대문구  364962  349308  15654  56284   4.29
# 도봉구   345041  342861   2180  54293   0.63
# 강북구   327511  323862   3649  57002   1.11
# 서대문구  324871  312311  12560  49645   3.87
# 성동구   314551  306532   8019  41752   2.55
# ...

# %%
s3['고령자비율'] = (s3['고령자']/s3['총인구'])*100
s3
# Out:
#          총인구     한국인    외국인    고령자  외국인비율      고령자비율
# 자치구
# 송파구   671994  665282   6712  77978   1.00  11.603973
# 강서구   608361  601696   6665  77381   1.10  12.719586
# 강남구   557865  552976   4889  65859   0.88  11.805544
# 노원구   555803  551902   3901  75081   0.70  13.508563
# 관악구   522292  504445  17847  70807   3.42  13.556976
# 은평구   490253  485902   4351  75535   0.89  15.407351
# 양천구   473087  469221   3866  56070   0.82  11.851943
# 성북구   453902  442226  11676  66896   2.57  14.737983
# 서초구   445164  440954   4210  54055   0.95  12.142716
# 구로구   440396  408369  32027  59838   7.27  13.587317
# 강동구   438225  434027   4198  56983   0.96  13.003138
# 중랑구   411552  406868   4684  59992   1.14  14.577016
# 동작구   406715  394353  12362  57711   3.04  14.189543
# 영등포구  403988  369128  34860  54704   8.63  13.540996
# 마포구   385624  374742  10882  50122   2.82  12.997635
# 광진구   371671  357149  14522  44470   3.91  11.964883
# 동대문구  364962  349308  15654  56284   4.29  15.421880
# ...

# %% [markdown]
# # 기술 통계정보
# 1. 아래를 조회하는데 합계 행은 빼고 계산한다.
# 1. 총인구 컬럼의 평균, 합계, 중위값, 표준편차, 분산, 데이터개수
# 1. 외국인과 고령자의 평균, 표준편차 조회
# 1. 외국인이 가장 적은 행을 조회

# %%
s3[['총인구']].agg(['mean','sum','median','std','var','count']).T
# Out:
#          mean         sum    median            std           var  count
# 총인구  404482.8  10112070.0  406715.0  128664.735948  1.655461e+10   25.0

# %%
s3[['외국인','고령자']].agg(['mean','std'])
# Out:
#                외국인           고령자
# mean  10927.120000  55296.800000
# std    8369.590678  15035.905515

# %%
s3.loc[[s3['외국인'].idxmin()]]
# Out:
#          세대     총인구      남자      여자     한국인   한국인남자   한국인여자   외국인  남자외국인  \
# 자치구
# 도봉구  137479  345041  168833  176208  342861  168009  174852  2180    824
#
#      여자외국인  세대당인구    고령자     외국인비율      고령자비율
# 자치구
# 도봉구   1356   2.49  54293  0.631809  15.735231

# %%
s3.mean()
# Out:
# 세대       169504.400000
# 총인구      404482.800000
# 남자       197939.240000
# 여자       206543.560000
# 한국인      393555.680000
# 한국인남자    192700.280000
# 한국인여자    200855.400000
# 외국인       10927.120000
# 남자외국인      5238.960000
# 여자외국인      5688.160000
# 세대당인구         2.303600
# 고령자       55296.800000
# 외국인비율         3.162069
# 고령자비율        13.970562
# dtype: float64

# %% [markdown]
# # DataFrame 병합하기
# ### seoul_cctv.csv 파일
# - 서울 자치구 연도별 CCTV 데이터 셋 [서울열린데이터광장](http://data.seoul.go.kr/dataList/OA-2734/C/1/datasetView.do)
#
#
# 1. seoul_cctv.csv 파일을 DataFrame으로 읽기
# 2. 서울시 자치구별 인구 DataFrame과 서울시 자치구 CCTV 데이터 셋을 **자치구명을 기준으로** 결합하여 하나의 DataFrame으로 만드시오.

# %%
sc1 = pd.read_csv('Seoul_cctv.csv')
sc1.shape
# Out:
# (25, 4)

# %%
sc1.head()
# Out:
#    기관명  2014년 CCTV 수  2015년 CCTV 수  2016년 CCTV 수
# 0  강남구           430           584           932
# 1  강동구            99           155           377
# 2  강북구           120           138           204
# 3  강서구           258           184            81
# 4  관악구           260           390           613

# %%
sc1['기관명']
# Out:
# 0      강남구
# 1      강동구
# 2      강북구
# 3      강서구
# 4      관악구
# 5      광진구
# 6      구로구
# 7      금천구
# 8      노원구
# 9      도봉구
# 10    동대문구
# 11     동작구
# 12     마포구
# 13    서대문구
# 14     서초구
# 15     성동구
# 16     성북구
# 17     송파구
# 18     양천구
# 19    영등포구
# 20     용산구
# 21     은평구
# 22     종로구
# 23      중구
# 24     중랑구
# Name: 기관명, dtype: object

# %%
s1.merge(sc1,left_on='자치구',right_on='기관명',how='right')
# Out:
#      자치구      세대     총인구      남자      여자     한국인   한국인남자   한국인여자    외국인  \
# 0    강남구  231219  557865  267314  290551  552976  264834  288142   4889
# 1    강동구  177490  438225  217570  220655  434027  215588  218439   4198
# 2    강북구  143139  327511  159853  167658  323862  158440  165422   3649
# 3    강서구  256042  608361  296098  312263  601696  292871  308825   6665
# 4    관악구  258536  522292  262428  259864  504445  253911  250534  17847
# 5    광진구  161407  371671  180206  191465  357149  173946  183203  14522
# 6    구로구  171751  440396  220903  219493  408369  202731  205638  32027
# 7    금천구  106333  253344  129791  123553  234238  119023  115215  19106
# 8    노원구  217999  555803  269762  286041  551902  268144  283758   3901
# 9    도봉구  137479  345041  168833  176208  342861  168009  174852   2180
# 10  동대문구  160489  364962  180381  184581  349308  174476  174832  15654
# 11   동작구  173544  406715  197848  208867  394353  192215  202138  12362
# ...

# %%
s2.join(sc1.set_index('기관명'))
# Out:
#            총인구      한국인     외국인      고령자  2014년 CCTV 수  2015년 CCTV 수  \
# 자치구
# 합계    10112070  9838892  273178  1382420           NaN           NaN
# 종로구     164348   154549    9799    26429         314.0         211.0
# 중구      135139   126082    9057    21655         190.0          72.0
# 용산구     245411   229909   15502    37238         218.0         112.0
# 성동구     314551   306532    8019    41752          91.0         241.0
# 광진구     371671   357149   14522    44470          78.0          53.0
# 동대문구    364962   349308   15654    56284          23.0         198.0
# 중랑구     411552   406868    4684    59992         121.0         177.0
# 성북구     453902   442226   11676    66896          78.0         360.0
# 강북구     327511   323862    3649    57002         120.0         138.0
# 도봉구     345041   342861    2180    54293         159.0          42.0
# 노원구     555803   551902    3901    75081          57.0         451.0
# ...

# %%
s1_cctv_join = s2.join(sc1.set_index('기관명'),how='inner')
s1_cctv_join
# Out:
#          총인구     한국인    외국인    고령자  2014년 CCTV 수  2015년 CCTV 수  2016년 CCTV 수
# 종로구   164348  154549   9799  26429           314           211           630
# 중구    135139  126082   9057  21655           190            72           348
# 용산구   245411  229909  15502  37238           218           112           398
# 성동구   314551  306532   8019  41752            91           241           265
# 광진구   371671  357149  14522  44470            78            53           174
# 동대문구  364962  349308  15654  56284            23           198           579
# 중랑구   411552  406868   4684  59992           121           177           109
# 성북구   453902  442226  11676  66896            78           360           204
# 강북구   327511  323862   3649  57002           120           138           204
# 도봉구   345041  342861   2180  54293           159            42           386
# 노원구   555803  551902   3901  75081            57           451           516
# ...

# %% [markdown]
# # Groupby와 집계
# ## forestfire.csv 파일
# - 포르투칼 북서부 산림 산불관련 데이터 셋 [UCI Machine learning repository](https://archive.ics.uci.edu/ml/datasets/forest+fires)
#
#
# 1. forestfire.csv 파일을 DataFrame으로 읽기
# 1. 어떤 컬럼들이 변수형 컬럼인지 확인.
# 1. 월(month)과 요일(day) 의 고유한(unique) 값들과 각각의 행수 조회
# 1. 요일(day) 별 wind의 평균을 조회
# 1. 요일(day) 별 wind, rain의 평균을 조회
# 1. 요일(day) 별 wind, rain의 평균과 합계과 개수 조회
# 1. 요일(day) 별로 wind는 평균을 rain은 합계와 최대값을 조회
# 1. 월(month) 그리고 요일별(day) temp의 최대값과 최소값을 조회
# 1. X좌표(X), Y좌표(Y)별 temp의 평균울 pivot table로 조회

# %%
ff = pd.read_csv('forestfire.csv')
ff.shape
ff
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
ff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   FFMC    517 non-null    float64
#  5   DMC     517 non-null    float64
#  6   DC      517 non-null    float64
#  7   ISI     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   RH      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %%
# 어떤 컬럼들이 범주형 컬럼인지 확인.
ff['X'].nunique()
ff['X'].value_counts()
ff['X'].unique()
# Out:
# array([7, 8, 6, 5, 4, 2, 9, 1, 3], dtype=int64)

# %%
ff['Y'].unique()
# Out:
# array([5, 4, 6, 3, 2, 9, 8], dtype=int64)

# %%
ff['DMC'].unique()
# Out:
# array([ 26.2,  35.4,  43.7,  33.3,  51.3,  85.3,  88.9, 145.4, 129.5,
#         88. ,  73.2,  70.8, 126.5, 133.3, 141.2,  35.8,  32.8,  27.9,
#         27.4,  78.5,  96.3, 110.9, 139.4, 142.4, 117.9, 149.3,  85.1,
#         91.8,  69.7,  75.6,  80.7,  41.5,  25.7,  60.6,  96.9, 108.3,
#         82.9,  62.3,  23.9,  52.2, 137. ,  99.6, 111.2, 114.3,  46.5,
#          9.3,  13.2,  75.3, 103.2,  48.3, 147.3,   6.8, 108. , 121.2,
#         90. ,   8. ,   2.4, 121.1,   3.7,  19.5,  30.7,  39.7, 124.1,
#         73.4,  37.9,  21.5,  80.9,  99.9, 131.7,  56.4,  68.6,  51.2,
#         50.1,  18.2, 127.1,  90.4,   9.1,  15.6,  48.5, 135.7,  41.9,
#         44. ,  37.6,   8.7, 150.3,  81.8,   3. ,  17.2,  23.3, 122.3,
#        175.1,  91.6, 157.3, 109.2, 138.1,  77. , 117.2, 170.9,  97.9,
#        112.4, 141.1, 167.6, 102.2, 152.6,  27.2,  27.8,  26.4,  25.4,
#         26.7,  27.5,   6.6,   4.9, 169.7, 183.1, 104.2, 100.2, 180.4,
# ...

# %%
ff['month'].unique()
# Out:
# array(['mar', 'oct', 'aug', 'sep', 'apr', 'jun', 'jul', 'feb', 'jan',
#        'dec', 'may', 'nov'], dtype=object)

# %%
ff.groupby('day')[['wind']].mean()
# Out:
#          wind
# day
# fri  4.494118
# mon  3.737838
# sat  3.758333
# sun  4.123158
# thu  3.711475
# tue  4.271875
# wed  3.912963

# %%
ff.groupby('day')[['wind','rain']].mean()
# Out:
#          wind      rain
# day
# fri  4.494118  0.018824
# mon  3.737838  0.000000
# sat  3.758333  0.000000
# sun  4.123158  0.010526
# thu  3.711475  0.000000
# tue  4.271875  0.131250
# wed  3.912963  0.003704

# %%
ff.groupby('day')[['wind','rain']].agg(['mean','sum','count'])
# Out:
#          wind                   rain
#          mean    sum count      mean  sum count
# day
# fri  4.494118  382.0    85  0.018824  1.6    85
# mon  3.737838  276.6    74  0.000000  0.0    74
# sat  3.758333  315.7    84  0.000000  0.0    84
# sun  4.123158  391.7    95  0.010526  1.0    95
# thu  3.711475  226.4    61  0.000000  0.0    61
# tue  4.271875  273.4    64  0.131250  8.4    64
# wed  3.912963  211.3    54  0.003704  0.2    54

# %%
ff.groupby('day').agg({'wind':'mean',
                      'rain':['sum','max']})
# Out:
#          wind rain
#          mean  sum  max
# day
# fri  4.494118  1.6  1.4
# mon  3.737838  0.0  0.0
# sat  3.758333  0.0  0.0
# sun  4.123158  1.0  1.0
# thu  3.711475  0.0  0.0
# tue  4.271875  8.4  6.4
# wed  3.912963  0.2  0.2

# %%
ff.groupby(['month','day'])[['temp']].agg(['max','min'])
# Out:
#            temp
#             max   min
# month day
# apr   fri  16.7  16.7
#       mon  10.9  10.9
#       sat   9.3   9.3
#       sun  17.6  13.4
#       thu   5.8   5.8
# ...         ...   ...
# sep   sat  30.2  15.4
#       sun  28.3  12.2
#       thu  27.7  12.9
#       tue  24.3  13.1
#       wed  26.4  10.5
#
# [64 rows x 2 columns]

# %%
ff_df = ff.groupby(['month','day'])[['temp']].agg(['max','min'])

# %%
#DataFrame을 한행씩 제공하는 generator
for row in ff_df.iterrows():
    print(row)
# Out:
# (('apr', 'fri'), temp  max    16.7
#       min    16.7
# Name: (apr, fri), dtype: float64)
# (('apr', 'mon'), temp  max    10.9
#       min    10.9
# Name: (apr, mon), dtype: float64)
# (('apr', 'sat'), temp  max    9.3
#       min    9.3
# Name: (apr, sat), dtype: float64)
# (('apr', 'sun'), temp  max    17.6
#       min    13.4
# Name: (apr, sun), dtype: float64)
# (('apr', 'thu'), temp  max    5.8
#       min    5.8
# Name: (apr, thu), dtype: float64)
# (('apr', 'wed'), temp  max    15.2
#       min    15.2
# Name: (apr, wed), dtype: float64)
# (('aug', 'fri'), temp  max    32.4
#       min    11.2
# Name: (aug, fri), dtype: float64)
# (('aug', 'mon'), temp  max    32.6
#       min     8.0
# Name: (aug, mon), dtype: float64)
# (('aug', 'sat'), temp  max    30.8
#       min     5.1
# Name: (aug, sat), dtype: float64)
# (('aug', 'sun'), temp  max    33.1
#       min    10.4
# Name: (aug, sun), dtype: float64)
# (('aug', 'thu'), temp  max    32.4
#       min    16.2
# ...

# %%
ff.groupby(['X','Y'])[['temp']].mean()
# Out:
#           temp
# X Y
# 1 2  20.747368
#   3  21.730000
#   4  19.606667
#   5  25.000000
# 2 2  18.532000
#   3  18.000000
#   4  21.833333
#   5  21.545000
# 3 3  24.200000
#   4  17.706977
#   5  14.714286
#   6  17.800000
# 4 3  21.045455
#   4  17.905556
#   5  17.864000
#   6  12.250000
# 5 4  18.617391
#   5  14.666667
#   6  20.000000
# 6 3  18.536000
#   4  15.388889
#   5  16.477551
#   6  25.900000
# 7 3  14.400000
#   4  17.875556
#   5  19.618182
#   6  19.750000
# 8 3  20.566667
#   4  21.300000
#   5  21.325000
#   6  19.815385
#   8  26.200000
# 9 4  24.225000
#   5  28.000000
#   6  20.500000
#   9  20.066667

# %%
ff.pivot_table(values='temp', index=['X','Y'], aggfunc='mean')
# Out:
#           temp
# X Y
# 1 2  20.747368
#   3  21.730000
#   4  19.606667
#   5  25.000000
# 2 2  18.532000
#   3  18.000000
#   4  21.833333
#   5  21.545000
# 3 3  24.200000
#   4  17.706977
#   5  14.714286
#   6  17.800000
# 4 3  21.045455
#   4  17.905556
#   5  17.864000
#   6  12.250000
# 5 4  18.617391
#   5  14.666667
#   6  20.000000
# 6 3  18.536000
#   4  15.388889
#   5  16.477551
#   6  25.900000
# 7 3  14.400000
#   4  17.875556
#   5  19.618182
#   6  19.750000
# 8 3  20.566667
#   4  21.300000
#   5  21.325000
#   6  19.815385
#   8  26.200000
# 9 4  24.225000
#   5  28.000000
#   6  20.500000
#   9  20.066667

# %%
ff.pivot_table(values='temp', index=['Y'],columns=['X'], aggfunc='mean')
# Out:
# X          1          2          3          4          5          6  \
# Y
# 2  20.747368  18.532000        NaN        NaN        NaN        NaN
# 3  21.730000  18.000000  24.200000  21.045455        NaN  18.536000
# 4  19.606667  21.833333  17.706977  17.905556  18.617391  15.388889
# 5  25.000000  21.545000  14.714286  17.864000  14.666667  16.477551
# 6        NaN        NaN  17.800000  12.250000  20.000000  25.900000
# 8        NaN        NaN        NaN        NaN        NaN        NaN
# 9        NaN        NaN        NaN        NaN        NaN        NaN
#
# X          7          8          9
# Y
# 2        NaN        NaN        NaN
# 3  14.400000  20.566667        NaN
# 4  17.875556  21.300000  24.225000
# 5  19.618182  21.325000  28.000000
# 6  19.750000  19.815385  20.500000
# 8        NaN  26.200000        NaN
# 9        NaN        NaN  20.066667

# %%
ff.pivot_table(values='temp', index='month', columns='day', aggfunc=['max', 'min'])
# Out:
#         max                                       min                          \
# day     fri   mon   sat   sun   thu   tue   wed   fri   mon   sat   sun   thu
# month
# apr    16.7  10.9   9.3  17.6   5.8   NaN  15.2  16.7  10.9   9.3  13.4   5.8
# aug    32.4  32.6  30.8  33.1  32.4  33.3  30.8  11.2   8.0   5.1  10.4  16.2
# dec     2.2   4.6   NaN   4.8   5.1   5.1   5.1   2.2   4.6   NaN   4.8   5.1
# feb    15.7  13.9  15.4  12.4   6.7   5.1   8.8   7.5   5.3   4.6   4.2   6.7
# jan     NaN   NaN   5.3   5.2   NaN   NaN   NaN   NaN   NaN   5.3   5.2   NaN
# jul    22.9  23.0  25.3  29.3  30.2  26.9  19.3  13.4  17.9  16.6  18.2  27.2
# jun    23.2  20.7  24.5  22.2  26.4   NaN  28.0  19.2  14.3  10.6  14.3  22.7
# mar    18.8  16.1  17.4  12.4  18.2  15.8  15.9   8.2   8.3  11.6   5.5   5.3
# may    18.0   NaN  11.3   NaN   NaN   NaN   NaN  18.0   NaN  11.3   NaN   NaN
# nov     NaN   NaN   NaN   NaN   NaN  11.8   NaN   NaN   NaN   NaN   NaN   NaN
# ...
