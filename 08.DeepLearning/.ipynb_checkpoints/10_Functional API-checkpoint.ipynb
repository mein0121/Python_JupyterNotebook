# %% [markdown]
# # Functional API
# - Sequential 모델은 각 Layer들의 입력과 출력이 하나라고 가정한다. 그리고 각각의 Layer(입력층, 은닉층, 출력층)들을 차례대로 쌓아 구성한다.
# - 함수형 API를 사용하면 **다중입력, 다중출력, 그래프 형태**의 다양한 형태의 모델을 유연하게 구성할 수 있다.
#
# - Functional API는 직접 텐서들의 입출력을 다룬다.
# - 함수호출 처럼 Layer를 이용하여 텐서를 입력 받고 출력하는 형식으로 모델을 구현한다.
#     - 코드상에서는 Layer를 입력받는 형식으로 작성한다.
#
#
# ```
# input_tensor = Input(shape=(16,))
# dense = layers.Dense(32, activation='relu')(input_tensor)
# output_tensor = layers.Dense(1, activation='sigmoid')(dense)
#
# model = models.Model(input_tensor, output_tensor)
# ```

# %%
# 매직메소드
class Test:
    def __init__(self, name):
        self.name = name
    
    def __call__(self):# 객체를 함수처럼 호출할 수 있게 해주는 특수메소드
        print("__call__", self.name)
        
    def __str__(self):
        return "문자열"
        
    def m(self):
        print('M')

# %%
t = Test("홍길동")

# %%
t.m()
# Out:
# M

# %%
str(t)
# Out:
# '문자열'

# %%
Test("ghd")()
# Out:
# __call__ ghd

# %% [markdown]
# ## Sequential, Functional API

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models

# %% [markdown]
# ### Sequential

# %%
seq_model = keras.Sequential()
seq_model.add(layers.Input(shape=(32,32,3)))
seq_model.add(layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
seq_model.add(layers.Flatten())
seq_model.add(layers.Dense(units=256, activation='relu'))
seq_model.add(layers.Dense(units=10, activation='softmax', name='output_layer'))
seq_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               16777472
# _________________________________________________________________
# output_layer (Dense)         (None, 10)                2570
# =================================================================
# Total params: 16,781,834
# Trainable params: 16,781,834
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Functional

# %%
input_tensor = layers.Input(shape=(32,32,3))

conv_tensor = layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(input_tensor)

pool_tensor = layers.MaxPooling2D(padding="same")(conv_tensor)

flatten_tensor = layers.Flatten()(pool_tensor)

dense_tensor = layers.Dense(units=256, activation='relu')(flatten_tensor)
dense_tensor2 = layers.Dense(units=128)(dense_tensor)

bn_tensor = layers.BatchNormalization()(dense_tensor2)
relu_tensor = layers.ReLU()(bn_tensor)

output_tensor = layers.Dense(units=10, activation="softmax")(relu_tensor)

fn_model = models.Model(input_tensor, output_tensor) # (입력텐서, 출력텐서)

fn_model.summary()

# fn_model.predict(x)

# dense_tensor2
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               4194560
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 4,231,050
# Trainable params: 4,230,794
# Non-trainable params: 256
# _________________________________________________________________

# %%
keras.utils.plot_model(fn_model, show_shapes=True)

# %%
input_tensor = layers.Input(shape=(32,32,3))
x = layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(input_tensor)
x = layers.MaxPooling2D(padding="same")(x)

x = layers.Flatten()(x)

x = layers.Dense(units=256, activation='relu')(x)
x = layers.Dense(units=128)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)

output_tensor = layers.Dense(units=10, activation="softmax")(x)

fn_model = models.Model(input_tensor, output_tensor) # (입력텐서, 출력텐서)

fn_model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               4194560
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 4,231,050
# Trainable params: 4,230,794
# Non-trainable params: 256
# _________________________________________________________________

# %% [markdown]
# ## 레이어를 합치는 함수
# - concatenate(list, axis=-1)
#     - 레이어들을 합친다
#     - list: 합칠 레이어들을 리스트에 묶어 전달
#     - axis: 합칠 기준축. (기본값: -1 : 마지막 축기준)
# - add(list), substract(list), multiply(list)
#     - 같은 index의 값들을 계산해서(더하기, 빼기, 곱하기) 하나의 레이어로 만든다.
#     - list: 합칠 레이어들을 리스트에 묶어 전달

# %%
# Residual block
input_tensor = layers.Input((32,32,3))
x = layers.Conv2D(64, kernel_size=3, padding='same', activation='relu')(input_tensor)
x1 = layers.Conv2D(64, kernel_size=3, padding="same")(x)
b1 = layers.BatchNormalization()(x1)
add1 = layers.add([x,b1])
r = layers.ReLU()(add1)

r_block_model = models.Model(input_tensor, r)

# %%
r_block_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   1792        input_11[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 64)   0           conv2d_9[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 32, 32, 64)   0           add[0][0]
# ==================================================================================================
# Total params: 38,976
# Trainable params: 38,848
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(r_block_model, show_shapes=True)

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 0.23.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author: None
# Author-email: None
# License: new BSD
# Location: c:\users\mein0\anaconda3\envs\tf2\lib\site-packages
# Requires: threadpoolctl, scipy, numpy, joblib
# Required-by:

# %%
# !pip install scikit-learn # scikitlearn install

# %% [markdown]
# ### 다중 출력 모델
# - 가정
#     - iris 데이터셋에서 꽃받침의 너비와 높이로 꽃입의 너비, 높이, 꽃 종류를 예측하는 모델
#     - 출력결과가 3개가 나와야 한다.
# - X: 꽃받침 너비, 높이
# - y: 꽃잎 너비, 높이, 꽃 종류

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
X, y = iris['data'], iris['target']
X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %%
X[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
y1 = X[:,2] # 꽃잎의 너비
y2 = X[:,3] # 꽃잎의 높이
y3 = y # 품종

X = X[:,[0,1]]

# %%
y1.shape,y2.shape,y3.shape, X.shape
# Out:
# ((150,), (150,), (150,), (150, 2))

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models

# %%
input_tensor = layers.Input((2, ))
x = layers.Dense(units=16, activation='relu')(input_tensor)
x = layers.Dense(units=8, activation='relu')(x)
output1 = layers.Dense(units=1, name='petal_width_output')(x)  # 꽃잎의 너비 예측 (Regression: unit=1, activation=없음)
output2 = layers.Dense(units=1, name='petal_length_output')(x) # 꽃잎의 높이 예측 (Regression: unit=1, activation=없음)
output3 = layers.Dense(units=3, activation='softmax', name='species_output')(x) # 품종 예측(다중분류: units: class개수(3), activation='softmax')

model = models.Model(input_tensor, [output1,output2,output3]) # Model(input, output) # input, output이 여러개인 경우 리스트로 묶는다.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           48          input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            136         dense_1[0][0]
# __________________________________________________________________________________________________
# petal_width_output (Dense)      (None, 1)            9           dense_2[0][0]
# __________________________________________________________________________________________________
# petal_length_output (Dense)     (None, 1)            9           dense_2[0][0]
# __________________________________________________________________________________________________
# species_output (Dense)          (None, 3)            27          dense_2[0][0]
# ==================================================================================================
# Total params: 229
# Trainable params: 229
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
# compile
model.compile(optimizer='adam',
              loss=['mse','mse','sparse_categorical_crossentropy'], 
              # 출력이 3개 - 각각의 loss를 순서대로 리스트로 묶어서 제공
              # 역전파를 통해 weight를 업데이트할때는 위 세개의 loss를 더한 총 loss로 역전파 처리
             )

# %%
history = model.fit(X,[y1,y2,y3],
                    epochs=100,
                    validation_split=0.1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 2s
# 5/5 [==============================] - 0s 25ms/step - loss: 8.1124 - petal_width_output_loss: 5.3689 - petal_length_output_loss: 1.1793 - species_output_loss: 1.5642 - val_loss: 12.6211 - val_petal_width_output_loss: 10.9908 - val_petal_length_output_loss: 0.0421 - val_species_output_loss: 1.5882
# Epoch 12/100
# 5/5 [==============================] - 0s 28ms/step - loss: 8.0025 - petal_width_output_loss: 5.2279 - petal_length_output_loss: 1.2530 - species_output_loss: 1.5216 - val_loss: 12.0356 - val_petal_width_output_loss: 10.3901 - val_petal_length_output_loss: 0.0521 - val_species_output_loss: 1.5934
# Epoch 13/100
# 5/5 [==============================] - 0s 26ms/step - loss: 7.8880 - petal_width_output_loss: 5.0795 - petal_length_output_loss: 1.2149 - species_output_loss: 1.5936 - val_loss: 11.4884 - val_petal_width_output_loss: 9.8309 - val_petal_length_output_loss: 0.0622 - val_species_output_loss: 1.5953
# Epoch 14/100
# 5/5 [==============================] - 0s 27ms/step - loss: 7.8978 - petal_width_output_loss: 5.0234 - petal_length_output_loss: 1.2509 - species_output_loss: 1.6235 - val_loss: 10.9694 - val_petal_width_output_loss: 9.3047 - val_petal_length_output_loss: 0.0714 - val_species_output_loss: 1.5933
# Epoch 15/100
# 5/5 [==============================] - 0s 23ms/step - loss: 7.2405 - petal_width_output_loss: 4.3201 - petal_length_output_loss: 1.3412 - species_output_loss: 1.5792 - val_loss: 10.5553 - val_petal_width_output_loss: 8.8893 - val_petal_length_output_loss: 0.0726 - val_species_output_loss: 1.5933
# Epoch 16/100
# 5/5 [==============================] - 0s 24ms/step - loss: 7.0812 - petal_width_output_loss: 4.1165 - petal_length_output_loss: 1.3039 - species_output_loss: 1.6607 - val_loss: 10.1826 - val_petal_width_output_loss: 8.5200 - val_petal_length_output_loss: 0.0703 - val_species_output_loss: 1.5922
# Epoch 17/100
# 5/5 [==============================] - 0s 21ms/step - loss: 6.7545 - petal_width_output_loss: 3.8215 - petal_length_output_loss: 1.3843 - species_output_loss: 1.5486 - val_loss: 9.8508 - val_petal_width_output_loss: 8.1969 - val_petal_length_output_loss: 0.0652 - val_species_output_loss: 1.5887
# Epoch 18/100
# 5/5 [==============================] - 0s 19ms/step - loss: 7.0149 - petal_width_output_loss: 4.1231 - petal_length_output_loss: 1.2536 - species_output_loss: 1.6381 - val_loss: 9.4235 - val_petal_width_output_loss: 7.7802 - val_petal_length_output_loss: 0.0671 - val_species_output_loss: 1.5762
# Epoch 19/100
# 5/5 [==============================] - 0s 20ms/step - loss: 6.6094 - petal_width_output_loss: 3.7192 - petal_length_output_loss: 1.2273 - species_output_loss: 1.6629 - val_loss: 9.1145 - val_petal_width_output_loss: 7.4823 - val_petal_length_output_loss: 0.0617 - val_species_output_loss: 1.5706
# Epoch 20/100
# 5/5 [==============================] - 0s 33ms/step - loss: 6.3353 - petal_width_output_loss: 3.5590 - petal_length_output_loss: 1.2193 - species_output_loss: 1.5570 - val_loss: 8.8265 - val_petal_width_output_loss: 7.2087 - val_petal_length_output_loss: 0.0557 - val_species_output_loss: 1.5622
# Epoch 21/100
100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.2409 - petal_width_output_loss: 1.6655 - petal_length_output_loss: 0.3537 - species_output_loss: 1.2217 - val_loss: 3.5730 - val_petal_width_output_loss: 2.1993 - val_petal_length_output_loss: 0.2461 - val_species_output_loss: 1.1276
# Epoch 53/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.2260 - petal_width_output_loss: 1.6790 - petal_length_output_loss: 0.3376 - species_output_loss: 1.2093 - val_loss: 3.5312 - val_petal_width_output_loss: 2.1484 - val_petal_length_output_loss: 0.2603 - val_species_output_loss: 1.1225
# Epoch 54/100
# 5/5 [==============================] - 0s 27ms/step - loss: 3.1803 - petal_width_output_loss: 1.6155 - petal_length_output_loss: 0.3203 - species_output_loss: 1.2444 - val_loss: 3.4180 - val_petal_width_output_loss: 2.0433 - val_petal_length_output_loss: 0.2621 - val_species_output_loss: 1.1127
# Epoch 55/100
# 5/5 [==============================] - 0s 19ms/step - loss: 3.1365 - petal_width_output_loss: 1.6072 - petal_length_output_loss: 0.3113 - species_output_loss: 1.2180 - val_loss: 3.3574 - val_petal_width_output_loss: 1.9796 - val_petal_length_output_loss: 0.2714 - val_species_output_loss: 1.1064
# Epoch 56/100
# 5/5 [==============================] - 0s 19ms/step - loss: 3.0213 - petal_width_output_loss: 1.5093 - petal_length_output_loss: 0.2980 - species_output_loss: 1.2140 - val_loss: 3.3736 - val_petal_width_output_loss: 1.9721 - val_petal_length_output_loss: 0.2925 - val_species_output_loss: 1.1091
# Epoch 57/100
# 5/5 [==============================] - 0s 30ms/step - loss: 3.0688 - petal_width_output_loss: 1.5947 - petal_length_output_loss: 0.2961 - species_output_loss: 1.1780 - val_loss: 3.3042 - val_petal_width_output_loss: 1.9043 - val_petal_length_output_loss: 0.2988 - val_species_output_loss: 1.1011
# Epoch 58/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.9513 - petal_width_output_loss: 1.4820 - petal_length_output_loss: 0.2910 - species_output_loss: 1.1783 - val_loss: 3.2472 - val_petal_width_output_loss: 1.8455 - val_petal_length_output_loss: 0.3063 - val_species_output_loss: 1.0954
# Epoch 59/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8974 - petal_width_output_loss: 1.4561 - petal_length_output_loss: 0.2679 - species_output_loss: 1.1734 - val_loss: 3.2624 - val_petal_width_output_loss: 1.8374 - val_petal_length_output_loss: 0.3258 - val_species_output_loss: 1.0992
# Epoch 60/100
# 5/5 [==============================] - 0s 25ms/step - loss: 2.7832 - petal_width_output_loss: 1.3520 - petal_length_output_loss: 0.2610 - species_output_loss: 1.1702 - val_loss: 3.2849 - val_petal_width_output_loss: 1.8332 - val_petal_length_output_loss: 0.3473 - val_species_output_loss: 1.1044
# Epoch 61/100
# 5/5 [==============================] - 0s 24ms/step - loss: 2.6596 - petal_width_output_loss: 1.2667 - petal_length_output_loss: 0.2613 - species_output_loss: 1.1316 - val_loss: 3.4239 - val_petal_width_output_loss: 1.9469 - val_petal_length_output_loss: 0.3664 - val_species_output_loss: 1.1107
# Epoch 62/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.6092 - petal_width_output_loss: 1.1891 - petal_length_output_loss: 0.2657 - species_output_loss: 1.1543 - val_loss: 3.4781 - val_petal_width_output_loss: 2.0115 - val_petal_length_output_loss: 0.3568 - val_species_output_loss: 1.1098
# Epoch 63/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.4612 - petal_width_output_loss: 1.0871 - petal_length_output_loss: 0.2572 - species_output_loss: 1.1169 - val_loss: 3.1313 - val_petal_width_output_loss: 1.7160 - val_petal_length_output_loss: 0.3197 - val_species_output_loss: 1.0956
# Epoch 64/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.4361 - petal_width_output_loss: 1.0356 - petal_length_output_loss: 0.2589 - species_output_loss: 1.1416 - val_loss: 2.7142 - val_petal_width_output_loss: 1.3596 - val_petal_length_output_loss: 0.2782 - val_species_output_loss: 1.0763
# Epoch 65/100
# 5/5 [==============================] - 0s 22ms/step - loss: 2.3131 - petal_width_output_loss: 0.9220 - petal_length_output_loss: 0.2554 - species_output_loss: 1.1357 - val_loss: 2.6401 - val_petal_width_output_loss: 1.2834 - val_petal_length_output_loss: 0.2783 - val_species_output_loss: 1.0784
# Epoch 66/100
# 5/5 [==============================] - 0s 24ms/step - loss: 2.2827 - petal_width_output_loss: 0.9075 - petal_length_output_loss: 0.2516 - species_output_loss: 1.1235 - val_loss: 2.7553 - val_petal_width_output_loss: 1.3587 - val_petal_length_output_loss: 0.3037 - val_species_output_loss: 1.0929
# Epoch 67/100
# 5/5 [==============================] - 0s 24ms/step - loss: 2.2404 - petal_width_output_loss: 0.9260 - petal_length_output_loss: 0.2322 - species_output_loss: 1.0822 - val_loss: 2.9284 - val_petal_width_output_loss: 1.4826 - val_petal_length_output_loss: 0.3378 - val_species_output_loss: 1.1079
# Epoch 68/100
# 5/5 [==============================] - 0s 28ms/step - loss: 2.2048 - petal_width_output_loss: 0.9079 - petal_length_output_loss: 0.2180 - species_output_loss: 1.0789 - val_loss: 2.9954 - val_petal_width_output_loss: 1.5154 - val_petal_length_output_loss: 0.3609 - val_species_output_loss: 1.1191
# Epoch 69/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.1537 - petal_width_output_loss: 0.8572 - petal_length_output_loss: 0.1942 - species_output_loss: 1.1023 - val_loss: 2.8899 - val_petal_width_output_loss: 1.4121 - val_petal_length_output_loss: 0.3604 - val_species_output_loss: 1.1174
# Epoch 70/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.1598 - petal_width_output_loss: 0.8899 - petal_length_output_loss: 0.2160 - species_output_loss: 1.0540 - val_loss: 2.9171 - val_petal_width_output_loss: 1.4134 - val_petal_length_output_loss: 0.3784 - val_species_output_loss: 1.1253
# Epoch 71/100
# 5/5 [==============================] - 0s 37ms/step - loss: 2.0962 - petal_width_output_loss: 0.8472 - petal_length_output_loss: 0.2080 - species_output_loss: 1.0410 - val_loss: 2.7849 - val_petal_width_output_loss: 1.2938 - val_petal_length_output_loss: 0.3710 - val_species_output_loss: 1.1201
# Epoch 72/100
# 5/5 [==============================] - 0s 35ms/step - loss: 2.0369 - petal_width_output_loss: 0.7770 - petal_length_output_loss: 0.1899 - species_output_loss: 1.0700 - val_loss: 2.6000 - val_petal_width_output_loss: 1.1413 - val_petal_length_output_loss: 0.3514 - val_species_output_loss: 1.1072
# Epoch 73/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.9290 - petal_width_output_loss: 0.7044 - petal_length_output_loss: 0.1863 - species_output_loss: 1.0383 - val_loss: 2.6550 - val_petal_width_output_loss: 1.1754 - val_petal_length_output_loss: 0.3686 - val_species_output_loss: 1.1111
# Epoch 74/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.9249 - petal_width_output_loss: 0.7378 - petal_length_output_loss: 0.1754 - species_output_loss: 1.0117 - val_loss: 2.6663 - val_petal_width_output_loss: 1.1816 - val_petal_length_output_loss: 0.3776 - val_species_output_loss: 1.1071
# Epoch 75/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.9476 - petal_width_output_loss: 0.7397 - petal_length_output_loss: 0.1815 - species_output_loss: 1.0264 - val_loss: 2.5796 - val_petal_width_output_loss: 1.1139 - val_petal_length_output_loss: 0.3712 - val_species_output_loss: 1.0945
# Epoch 76/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.9068 - petal_width_output_loss: 0.7160 - petal_length_output_loss: 0.1705 - species_output_loss: 1.0203 - val_loss: 2.6072 - val_petal_width_output_loss: 1.1275 - val_petal_length_output_loss: 0.3838 - val_species_output_loss: 1.0959
# Epoch 77/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.8258 - petal_width_output_loss: 0.6755 - petal_length_output_loss: 0.1663 - species_output_loss: 0.9839 - val_loss: 2.6412 - val_petal_width_output_loss: 1.1424 - val_petal_length_output_loss: 0.3974 - val_species_output_loss: 1.1014
# Epoch 78/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.8004 - petal_width_output_loss: 0.6415 - petal_length_output_loss: 0.1575 - species_output_loss: 1.0015 - val_loss: 2.6583 - val_petal_width_output_loss: 1.1472 - val_petal_length_output_loss: 0.4078 - val_species_output_loss: 1.1033
# Epoch 79/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.8108 - petal_width_output_loss: 0.6616 - petal_length_output_loss: 0.1675 - species_output_loss: 0.9817 - val_loss: 2.6031 - val_petal_width_output_loss: 1.0962 - val_petal_length_output_loss: 0.4053 - val_species_output_loss: 1.1016
# Epoch 80/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.7381 - petal_width_output_loss: 0.6111 - petal_length_output_loss: 0.1564 - species_output_loss: 0.9706 - val_loss: 2.5343 - val_petal_width_output_loss: 1.0397 - val_petal_length_output_loss: 0.4004 - val_species_output_loss: 1.0941
# Epoch 81/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.6778 - petal_width_output_loss: 0.5555 - petal_length_output_loss: 0.1491 - species_output_loss: 0.9733 - val_loss: 2.4540 - val_petal_width_output_loss: 0.9738 - val_petal_length_output_loss: 0.3920 - val_species_output_loss: 1.0882
# Epoch 82/100
# 5/5 [==============================] - 0s 29ms/step - loss: 1.7707 - petal_width_output_loss: 0.6383 - petal_length_output_loss: 0.1737 - species_output_loss: 0.9588 - val_loss: 2.3808 - val_petal_width_output_loss: 0.9133 - val_petal_length_output_loss: 0.3828 - val_species_output_loss: 1.0847
# Epoch 83/100
# 5/5 [==============================] - 0s 29ms/step - loss: 1.6402 - petal_width_output_loss: 0.5477 - petal_length_output_loss: 0.1488 - species_output_loss: 0.9437 - val_loss: 2.4565 - val_petal_width_output_loss: 0.9580 - val_petal_length_output_loss: 0.4013 - val_species_output_loss: 1.0972
# Epoch 84/100
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6374 - petal_width_output_loss: 0.5561 - petal_length_output_loss: 0.1404 - species_output_loss: 0.9409 - val_loss: 2.4633 - val_petal_width_output_loss: 0.9572 - val_petal_length_output_loss: 0.4065 - val_species_output_loss: 1.0995
# Epoch 85/100
# 5/5 [==============================] - 0s 25ms/step - loss: 1.5868 - petal_width_output_loss: 0.5152 - petal_length_output_loss: 0.1362 - species_output_loss: 0.9354 - val_loss: 2.3096 - val_petal_width_output_loss: 0.8460 - val_petal_length_output_loss: 0.3802 - val_species_output_loss: 1.0834
# Epoch 86/100
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5302 - petal_width_output_loss: 0.4659 - petal_length_output_loss: 0.1295 - species_output_loss: 0.9349 - val_loss: 2.2799 - val_petal_width_output_loss: 0.8226 - val_petal_length_output_loss: 0.3781 - val_species_output_loss: 1.0791
# Epoch 87/100
# 5/5 [==============================] - 0s 19ms/step - loss: 1.5506 - petal_width_output_loss: 0.5030 - petal_length_output_loss: 0.1367 - species_output_loss: 0.9109 - val_loss: 2.3818 - val_petal_width_output_loss: 0.8928 - val_petal_length_output_loss: 0.4034 - val_species_output_loss: 1.0856
# Epoch 88/100
# 5/5 [==============================] - 0s 29ms/step - loss: 1.5644 - petal_width_output_loss: 0.4998 - petal_length_output_loss: 0.1480 - species_output_loss: 0.9166 - val_loss: 2.5852 - val_petal_width_output_loss: 1.0325 - val_petal_length_output_loss: 0.4492 - val_species_output_loss: 1.1035
# Epoch 89/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.5821 - petal_width_output_loss: 0.5429 - petal_length_output_loss: 0.1442 - species_output_loss: 0.8949 - val_loss: 2.5795 - val_petal_width_output_loss: 1.0217 - val_petal_length_output_loss: 0.4524 - val_species_output_loss: 1.1055
# Epoch 90/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.5861 - petal_width_output_loss: 0.5193 - petal_length_output_loss: 0.1426 - species_output_loss: 0.9242 - val_loss: 2.3566 - val_petal_width_output_loss: 0.8651 - val_petal_length_output_loss: 0.4100 - val_species_output_loss: 1.0814
# Epoch 91/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.4216 - petal_width_output_loss: 0.4257 - petal_length_output_loss: 0.1156 - species_output_loss: 0.8802 - val_loss: 2.3256 - val_petal_width_output_loss: 0.8425 - val_petal_length_output_loss: 0.4064 - val_species_output_loss: 1.0766
# Epoch 92/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.4855 - petal_width_output_loss: 0.4680 - petal_length_output_loss: 0.1363 - species_output_loss: 0.8812 - val_loss: 2.3776 - val_petal_width_output_loss: 0.8755 - val_petal_length_output_loss: 0.4214 - val_species_output_loss: 1.0806
# Epoch 93/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.4547 - petal_width_output_loss: 0.4448 - petal_length_output_loss: 0.1257 - species_output_loss: 0.8843 - val_loss: 2.3809 - val_petal_width_output_loss: 0.8714 - val_petal_length_output_loss: 0.4255 - val_species_output_loss: 1.0840
# Epoch 94/100
# 5/5 [==============================] - 0s 29ms/step - loss: 1.4053 - petal_width_output_loss: 0.4263 - petal_length_output_loss: 0.1205 - species_output_loss: 0.8584 - val_loss: 2.2480 - val_petal_width_output_loss: 0.7806 - val_petal_length_output_loss: 0.4003 - val_species_output_loss: 1.0671
# Epoch 95/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.5125 - petal_width_output_loss: 0.4796 - petal_length_output_loss: 0.1486 - species_output_loss: 0.8843 - val_loss: 2.0371 - val_petal_width_output_loss: 0.6380 - val_petal_length_output_loss: 0.3571 - val_species_output_loss: 1.0419
# Epoch 96/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.3720 - petal_width_output_loss: 0.4007 - petal_length_output_loss: 0.1160 - species_output_loss: 0.8553 - val_loss: 2.1193 - val_petal_width_output_loss: 0.6913 - val_petal_length_output_loss: 0.3779 - val_species_output_loss: 1.0501
# Epoch 97/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.3663 - petal_width_output_loss: 0.3868 - petal_length_output_loss: 0.1177 - species_output_loss: 0.8619 - val_loss: 2.3859 - val_petal_width_output_loss: 0.8696 - val_petal_length_output_loss: 0.4403 - val_species_output_loss: 1.0760
# Epoch 98/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.3056 - petal_width_output_loss: 0.3785 - petal_length_output_loss: 0.1064 - species_output_loss: 0.8207 - val_loss: 2.5968 - val_petal_width_output_loss: 1.0104 - val_petal_length_output_loss: 0.4898 - val_species_output_loss: 1.0966
# Epoch 99/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.3683 - petal_width_output_loss: 0.4197 - petal_length_output_loss: 0.1197 - species_output_loss: 0.8288 - val_loss: 2.5359 - val_petal_width_output_loss: 0.9646 - val_petal_length_output_loss: 0.4786 - val_species_output_loss: 1.0927
# Epoch 100/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.4052 - petal_width_output_loss: 0.4242 - petal_length_output_loss: 0.1299 - species_output_loss: 0.8511 - val_loss: 2.2360 - val_petal_width_output_loss: 0.7608 - val_petal_length_output_loss: 0.4111 - val_species_output_loss: 1.0641

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
model.evaluate(X,[y1,y2,y3])
# Out:
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4411 - petal_width_output_loss: 0.4359 - petal_length_output_loss: 0.1511 - species_output_loss: 0.8542
# [1.4411351680755615,
#  0.43589848279953003,
#  0.15108400583267212,
#  0.8541526198387146]

# %%
# 추론
X[:2]
# Out:
# array([[5.1, 3.5],
#        [4.9, 3. ]])

# %%
model.predict(X[:2])
# Out:
# [array([[1.9160858],
#         [2.414584 ]], dtype=float32),
#  array([[0.41356876],
#         [0.61908793]], dtype=float32),
#  array([[0.5776344 , 0.24860547, 0.17376016],
#         [0.46634826, 0.30682614, 0.22682562]], dtype=float32)]

# %%
y1[:2], y2[:2], y3[:2]
# Out:
# (array([1.4, 1.4]), array([0.2, 0.2]), array([0, 0]))

# %% [markdown]
# ## 다중 입력 모델
# - 가정
#     - IRIS 꽃 데이터 + 꽃의 사진을 입력해서 꽃의 종류를 예측한다.
# - X: 꽃 데이터, 꽃 사진
# - y: 꽃 종류

# %%
iris_info_tensor = layers.Input((4, ))
x1 = layers.Dense(32, activation='relu')(iris_info_tensor)
x1 = layers.Dense(16, activation='relu')(x1)

iris_img_tensor = layers.Input((16,16,1))
x2 = layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(iris_img_tensor)
x2 = layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(x2)
x2 = layers.MaxPool2D(padding='same')(x2)
x3 = layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x2)
x3 = layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x3)
x3 = layers.MaxPool2D(padding='same')(x3)
x3 = layers.GlobalAveragePooling2D()(x3)

#합치기
x4 = layers.concatenate([x1, x3])
x5 = layers.Dropout(0,2)(x4)

output_tensor = layers.Dense(units=3, activation='softmax')(x5)

model = models.Model([iris_info_tensor, iris_img_tensor], output_tensor)

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_16 (InputLayer)           [(None, 16, 16, 1)]  0
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 32)   320         input_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 32)   9248        conv2d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 32)     0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     18496       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 4)]          0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_19[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 32)           160         input_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 4, 4, 64)     0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 16)           528         dense_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 80)           0           dense_19[0][0]
#                                                                  global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 80)           0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 3)            243         dropout_3[0][0]
# ==================================================================================================
# Total params: 65,923
# Trainable params: 65,923
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy', metrics=['accuracy'])
