# %% [markdown]
# # 데이터 파일 읽기
#
# - [서울시 코로나19 확진자 현황](http://data.seoul.go.kr/dataList/OA-20279/S/1/datasetView.do)
# ## 컬럼
# - ID : 확진자 ID. 발생순서대로 1씩증가하는 값
# - 확진일: 확진 날짜
# - 자치구: 확진 결과를 받은 지역구.
# - 여행력: 해외유입의 경우 국가명
# - 접촉력: 감염된 경로.
# - 현재상태: 퇴원, 사망, NA: 치료중

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid = pd.read_csv('data/corona19_seoul_2021-03-15.csv', index_col='ID')

# %%
covid.sort_values('ID', inplace=True)

# %% [markdown]
# # DataFrame 기본정보 조회

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30061 entries, 1 to 30061
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   확진일     30061 non-null  object
#  1   자치구     30061 non-null  object
#  2   여행력     976 non-null    object
#  3   접촉력     30061 non-null  object
#  4   현재상태    27143 non-null  object
# dtypes: object(5)
# memory usage: 1.4+ MB

# %%
covid.describe()
# Out:
#                확진일    자치구  여행력        접촉력   현재상태
# count        30061  30061  976      30061  27143
# unique         384     27  120        512      2
# top     2020-12-17     기타   미국  기타 확진자 접촉     퇴원
# freq           588   2000  329       9660  26738

# %%
covid.head()
# Out:
#            확진일  자치구  여행력        접촉력 현재상태
# ID
# 1   2020-01-24  강서구   중국       해외유입   퇴원
# 2   2020-01-30  강서구   중국       해외유입   퇴원
# 3   2020-01-30  중랑구  NaN   종로구 집단발병   퇴원
# 4   2020-01-30  종로구   중국       해외유입   퇴원
# 5   2020-01-31  마포구  NaN  기타 확진자 접촉   퇴원

# %% [markdown]
# ##  범주형 컬럼들의 고유값들 조회

# %%
covid['자치구'].unique()
# Out:
# array(['강서구', '중랑구', '종로구', '마포구', '성북구', '타시도', '송파구', '서대문구', '성동구',
#        '서초구', '구로구', '강동구', '은평구', '관악구', '금천구', '노원구', '동작구', '강남구',
#        '양천구', '동대문구', '광진구', '영등포구', '도봉구', '용산구', '강북구', '중구', '기타'],
#       dtype=object)

# %%
covid['여행력'].unique()
# Out:
# array(['중국', nan, '싱가폴', '베트남', '태국', '이탈리아', '프랑스', '필리핀', '독일, 프랑스',
#        '폴란드', '스페인', '영국', '오스트리아, 모로코, 프랑스', '미국',
#        '체코, 헝가리, 오스트리아, 이탈리아, 프랑스', '이탈리아, 프랑스', '프랑스, 독일', '스페인, 카타르',
#        '캐나다', '독일', '브라질,아르헨티아,칠레,볼리비아', '말레이시아, 인도네시아',
#        '아르헨티나, 볼리비아, 브라질', '유럽', '아시아', '멕시코, 미국', '브라질', '미국, 브라질',
#        '오스트리아', '아일랜드', '미국, 캐나다, 멕시코', '오세아니아', '일본', '포르투갈', '인도네시아',
#        '호주, 인도네시아', '터키', '프랑스, 스페인, 이탈리아, 독일, 네덜란드', '멕시코', '아프리카',
#        '러시아', '파키스탄', 'UAE', '방글라데시', '이라크', '카자흐스탄', '아랍에미리트', '인도',
#        '키르기스스탄', '우즈베키스탄', '페루', '미국, 멕시코', '나이지리아', '쿠웨이트', '모로코, 터키',
#        '홍콩', '사우디아라비아', '에콰도르', '케냐', '에티오피아', '이집트', '21263', '파라과이',
#        '키르기즈스탄', '우크라이나', '네팔', '카타르', '체코', '몰타', '우간다', '요르단', '이란',
#        '네덜란드', '에디오피아', '튀니지', '가나', '핀란드', '헝가리', '루마니아', '수단', '미얀마',
#        '28238', '크로아티아', '스웨덴', '벨기에', '모로코', '가봉', '아르헨티나', '호주', '알제리',
#        '알바니아', '남아공', '두바이', '리투아니아', '시리아', '탄자니아', '콩고', '코트디부아르',
#        '르완다', '싱가포르', '캄보디아', '스리랑카', '덴마크', '아이티공화국', '콩고민주공화국', '시에라리온',
#        '기타', '모리타니아', '에티오피나', '콜롬비아', '벨라루스', '레바논', '미국LA', '불가리아,터키',
#        '세네갈', '적도기니', '아제르바히잔', '아제르바이잔', '과테말라', '바레인', '베트남 사이공'],
#       dtype=object)

# %%
covid['접촉력'].unique()
# Out:
# array(['해외유입', '종로구 집단발병', '기타 확진자 접촉', '성동구 아파트 관리사무소', '타시도 확진자 접촉',
#        '은평성모병원', '명성교회', '감염경로 조사중', '동대문관련(교회pc방)', 'EZHLD',
#        '동대문관련(요양보호사)', 'Ace 손해보험', '성남 은혜의강 교회', '세브란스', '플링크(IT기업)',
#        '신 천 지', '삼성물산', '만민중앙교회', '서울아산병원', '이에스에스콤글로벌', 'ㅋㅋ트랜드', '의정부성모',
#        'Liquid Soul', '타시도 확진자 접촉 (의정부성모)', '위에화엔터테인먼트', '이태원 클럽 관련',
#        '삼성서울병원', '원어성경연구회', '영랜브란트미술학원', '은평구가족 관련', 'coupang',
#        '강남구 동인교회 관련 (구리시 일가족)', 'KB생명', '관악구 투석환자 관련',
#        '예수제자교회 한국대학생 선교회(CCC) 관련', '(인천계양구일가족관련) 연세나로학원', '연아나 뉴스클래스',
#        '부천 대웅제약', '수도권 개척교회모임', '서초구 가족관련', '안양 목회자 관련', '리치웨이', '삼성화재',
#        '양천구운동시설', '용인형제', '리치웨이 (명성하우징)', '리치웨이 (SJ투자회사)',
#        '리치웨이 (이민자 쉼터)', '리치웨이 (예수비젼성결교회)', '도봉구 요양시설 관련', '국방안보지원사령부',
#        '대전 꿈꾸는 교회', '대전 다단계 관련', '금천구 도정기회사 관련', '대자연 코리아', '강남구 역삼동 모임',
#        '예스병원', '강남구 오렌지라이프 관련', '서울시청역 시설개선공사 안전요원관련', '의왕 롯데 물류센터 관련',
#        '관악구 왕성교회', '강남구 소재 사무실', '현대카드 관악구 왕성교회', '관악구 중국동포 일가족',
#        '강남역삼동금융회사', '중랑구 일가족', '타시도 확진자 접촉 (의정부아파트관련)',
#        '강남구 사무실(V빌딩, 한화생명)', '강남 이동통신 종사자', '관악구 사무실 관련',
#        '타시도 확진자 접촉 (수원 베이비시터 관련)', '강남구 사무실 (K빌딩)', '종로구 지인모임 (신명투자)',
#        '강서구 요양시설 관련', '송파구 교회 관련', '선교회 소모임', '송파구 지인모임',
#        '강남구 커피전문점 (할리스)', '도봉구 가족관련', '성동구 가족관련', '관악구 요양병원', '강남구 판매업소',
#        '고양시 반석교회 관련 (케네디상가)', '롯데리아 종사자 모임', '골드트레인', '성북구 사랑제일교회 관련',
#        '되새김교회', '용인시 우리제일교회 관련', '중구 통일상가', '영등포 IFC몰 오케스트로',
#        '여의도 순복음교회 관련', '종로구 혜화경찰서 관련', '8.15서울도심집회', '강동구 어린이집',
#        '마포구 푸본생명콜센터', '현대커머셜', '성북구 체대입시 관련', '은평구 성경공부모임', '극단 산 관련',
#        '고대 안암병원 관련', '구로구 보성운수', '은평구 헤어콕 관련', '다래경매 관련', '노원구 빛가온교회 관련',
#        '서대문구 지인모임', '구로구 아파트 관련', 'KT가좌지사 관련', '동작구 스터디카페',
#        '동작구 소재 서울신학교', '강서구 병원관련', '롯데 자산개발 관련', '동작구 진흥글로벌', '한양대병원',
#        '관악구 가족모임', '중구 보험회사(현대해상)', '구로구 아파트 관련 (금천 축산업체)',
#        '강서구 서울대효요양병원', '동작구 닥터큐 관련', '영등포구 국회출입기자관련', '강동구 소재 병원',
#        '도봉구 운동시설', '동대문구 sk탁구클럽', '강남구 소재 아파트', '군인권센터', '영등포구 권능교회',
#        '동작구 요양시설 관련', '성북구 벧엘장로교회', '노원구 기도모임', '제주 게스트하우스 관련',
#        '중랑구 소재 체육시설', '기타 확진자 접촉 (동작구 소재 아파트)', '강서구 보안회사', '성북구 요양시설',
#        '관악구 에바다 관련', '강북구 일가족', '관악구 김혜근의원', '서초구 장애인교육시설', '광진구 혜민병원',
#        '노원구 손해보험 관련', '중구소재 은행 관련', '송파구 소재병원', '영등포 지인모임', '송파구 쿠팡 관련',
#        '강동구 BF모바일 관련', '은평구 수색성당', '강남구 소재 대우디오빌플러스', '영등포구 일련정종 서울포교소',
#        '종로구청 관련', '강남구 K보건산업', '서대문구 세브란스병원', '도봉구 건설현장', '강남구 통신판매업',
#        '건축설명회', '송파구 우리교회', '기타 확진자 접촉 (성남 서호주간센터)', '강남구 신도벤처타워',
#        '관악구 삼모스포렉스', '수도권 지인모임', '관악구 지인모임', '9월 송파구 지인모임', '서울지방국세청 관련',
#        '양천구 양천경찰서', '강남구 디와이디벨로먼트', '영등포구 소재 마트 관련', '강남구 소재 금융회사',
#        '타시도 확진자 접촉 (포천소망공동체요양원)', '영등포구 LG트윈타워', '동대문구 성경모임(발산대우주어린이집)',
#        '영등포 소재 증권회사', '도봉구 소재 아파트 관련', '프로그래머 지인모임', '도봉구 예마루데이케어센터',
#        '관악구 사랑나무 어린이집', '성동구 덕수고 야구부', '신도림 역사 관련', '종로구 서울대병원',
#        '중랑구 서울의료원', '동작구 부동산회사', '관악구 가족 관련 (가가호호데이케어센터)', '도봉구 다나병원',
#        '고양시부부관련(마포구어린이집&서초구우체국)', '관악구 식당관련', '강남구 삼성화재',
#        '마포구 서울디자인 고등학교', '관악구 휘트니스 관련', '서초구 LG 유플러스', '동작구 가족관련',
#        '강북구 북서울 꿈의교회', '강남승광빌딩 관련', '서초구 소재 카페 관련', '영등포구 방문판매업체 관련',
#        '부산시 방문주사 관련', '관악구 큰믿음유신감리교회', '영등포구 소모임', '서대문구 소재 장례식장',
#        '타시도 확진자 접촉 (강원 강릉시 지인모임)', '송파구 잠언의료기', '송파구 서민국수관련',
#        '중구 소재 빌딩 관련', '중구 소재 콜센터(외향산업)', '중랑구 이마트 상봉점', '강남구 해냄세무회계',
#        '강동구 행복데이케어센터', '강남서초 지인모임', '송파구 잠언의료기 (강남구 CJ텔레닉스)',
#        '기타 확진자 접촉 (경기도 SRC재활병원)', '관악구 삼모스포렉스Ⅱ', '송파구 소재 교회관련',
#        '수도권 지인모임 Ⅱ', '생일파티모임관련', '구로구 가족관련', '구로구 가족관련 (부천무용학원관련)',
#        '영등포구 가족관련', '용인시 동문골프 모임', '영등포구 가족관련 (송파구소재 건설현장)', '강서구 가족 관련',
#        '강남구 럭키사우나 관련', '용산구 소재 의류업체', '은평구 방문교사 관련', '도봉구 가족관련 Ⅱ',
#        '강남구 헬스장 관련', '송파구 소재 병원관련(뉴스타트)', '서울음악 교습 관련', '강남구 역삼역 관련',
#        '제주도 지인모임', '동대문구 한국산업인력공단', '동대문구 에이스희망케어센터 관련', '성동구 시장관련',
#        '영등포구 증권회사 관련', '송파구 시장 관련', '언론인 관련', '종로구 녹음실 관련', '서초구 빌딩 관련',
#        '강서구 보험회사 관련', '동작구 모조카페', '성동구 금호노인요양원 관련', '강서구 사우나 관련',
#        '중랑구 체육시설 관련', '노원구 재가요양서비스 관련', '서초구 사우나 관련',
#        '기타 확진자 접촉 (강남구 제약회사 관련)', '용산구 국군복지단', '수도권산악회(11월) 관련',
#        '성북구 가족 관련', '성동구 체육시설 관련', '강서구 소재 병원관련(11월)', '수도권 지인모임(11월) 관련',
#        '중구 제조업 공장 관련', '송파구 지인강원여행모임', '타시도 확진자 접촉 (충남아산전기공사업체관련)',
#        '강남구 콜센터 관련', '강서구 지인모임 관련(11월)', '강서구 경로당 관련', '도봉구 의류업작업장 관련',
#        '노원구 가족관련', '동창 운동 모임 관련', '서울시청(11월) 관련', '수도권 미술대학원/아이스하키 관련',
#        '동작구 가족관련(11월)', '서대문구 요양시설 관련', '강동구 소재 건설현장 관련', '도봉구 청련사 관련',
#        '서초구 소재 교회/교육원 관련', '노원구 의료기관 관련', '연세대 학생 관련', '서초구 어린이집 관련',
#        '강남구 연기학원 관련', '중구 성00 관련', '동대문구 고등학교 관련', '동작구 교회 기도처 관련',
#        '성동구 소재 PC방 관련', '서울대병원 발생 관련', '서초구 사우나Ⅱ 관련', '강남구 소재 병원 관련',
#        '강남구 음식점Ⅱ 관련', '동작구 임용단기고시 관련', '마포구 홍대새교회 관련', '송파구 사우나 관련',
#        '중구 소재 판매시설 관련', '강서구 댄스교습관련 시설', '지인-가족전파', '마포구 소재 노인복지시설 관련',
#        '강서구 댄스교습 연관 병원 관련', '노원구청 관련', '중랑구 실내 체육시설 Ⅱ 관련', '어플소모임 관련',
#        '중구 소재 보람상조회사 관련', '소규모 지인모임', '동대문구 체육시설 관련', '영등포구 회사 관련',
#        '노원구 체육시설 관련', '서초구 건설회사 관련', '마포구 홈쇼핑회사 관련', '춘천 연탄봉사모임 관련',
#        '구로구 소재 고등학교 관련', '동부구치소 관련', '제주여행(퇴직교사) 관련', '영등포구 학원 관련',
#        '종로구 소재 파고다타운 관련', '마포구 빌딩 관련', '저축 금융컨설팅 관련', '강남구 어학원 관련Ⅰ',
#        '노원구 소재 회사 관련', '노원구 소재 교회 관련', '엠넷체육관 지인', '성동구 소재 의료기관 관련',
#        '강남구 어학원 관련Ⅱ', '동대문구 지혜병원 관련', '강남구 소재 콜센터 관련',
#        '중구 소재 콜센터Ⅰ관련(동부화재)', '고려대학교 밴드동아리', '영등포구 소재 교회 관련',
#        '관악구 소재 음식점 관련', '송파구 체육시설 관련', '중구 소재 시장(남대문시장) 관련',
#        '성북구 소재 공연연습실', '영등포구 소재 콜센터 관련', '구로구 소재 보험회사 관련',
#        '송파구 소재 의료기관 관련', '중랑구 소재 병원 관련', '동작구 최비야 관련', '강남구 소재 요양병원',
#        '동작구 사우나 관련', '성북구 소재 의료기관', '중구 소재 콜센터Ⅱ 관련(메리츠화재)',
#        '성동구 소재 병원 관련', '용산구 소재 음식점 등 관련', '강남구 소재 마사지샵 관련', '강서구 교회 관련',
#        '마포구 소재 보험회사 관련', '구로구소재 고등학교 관련', '은평구 소재 역사관련', '서초구 소재 병원',
#        '중구 소재 콜센터(한전SCS) 관련', '영등포구 소재 의료기관', '성동구 병원 관련',
#        '강남구 소재 공기업 관련', '용산구 소재 건설현장 관련', '송파구 소재 병원관련(12월)',
#        '강북구 새노래교회 관련', '중구 소재 직장 관련', '아산병원', '구로구 소재 요양병원/요양원 관련',
#        '성북구 종교시설(장암교회) 관련', '구로구 소재 병원 관련', '중랑구 소재 종교시설 관련',
#        '동대문구 소재 교회관련', '상주 BTJ 열방센터 관련', '금천구 소재 교회 관련', '광진구 소재 병원 관련',
#        '용산구 음식점 관련', '종로구 소재 요양시설 관련', '강남구 콜센터Ⅱ 관련', '노원구 소재 병원 관련',
#        '강동구 지인모임 관련', '강남구 개인사저 경비팀', '양천구 소재 요양시설1 관련',
#        '송파구 소재 장애인 거주시설 관련', '강남구 소재 택시회사 관련', '중구 소재 콜센터(다은컨설팅)',
#        '서초구소재 종교시설 관련', '타시도 확진자 접촉(경기이천시물류센터관련)', '서초구 소재 종교시설 관련',
#        '관악구 소재 종교시설 관련', '동대문구 소재 어르신복지시설 관련', '구로구 소재 산후조리원 관련',
#        '양천구 소재 요양시설2 관련', '영등포구 소재 장례식장 관련', '강북구 소재 아동관련 시설',
#        '영등포 소재 의료기관 관련', '동대문구 소재 역사 관련', '서대문구 소재 의료기관/종교시설 관련',
#        '은평구 소재 병원1 관련', '양천구 소재 요양시설2 관련 ', '서대문구 소재 종교시설 관련',
#        '강북구 소재 교회 관련', '종로구 소재 사우나 관련', '종로구 소재 콜센터 관련', '강동구 소재 요양병원 관련',
#        '남부교도소 관련', '용산구 소재 미군기지 관련', '마포구 소재 종교시설', '병원 및 요양시설',
#        '송파구 소재 시장 관련', '광진구 소재 요양시설 관련', '강동구 가족관련',
#        '성동구 소재 거주시설/요양시설 관련', '강남구 소재 직장1 관련', '종로구 소재 요양시설2 관련',
#        '강남구 소재 사우나 관련', '동대문구 소재 현대대중사우나 관련', '구로구 소재 직장',
#        '노원구 소재 요양시설 관련', '강남구 소재 직장2 관련', '강남구 소재 직장4 관련',
#        '은평구 소재 병원2 관련', '동대문구 소재 대학교 관련', '동작구 소재 직장관련', '송파구 소재 고시텔 관련',
#        '도봉구 소재 어린이집 관련', '종로구 소재 직장 관련', '중구 소재 직장2 관련', '중구 소재 복지시설 관련',
#        '강남구 소재 선교회 교육시설 관련', '양천구 소재 직장 관련', '영등포구 소재 의료기관2 관련',
#        '성동구 소재 사우나 관련', '종로구 소재 빌딩관련', '강남구 소재 직장3 관련', '노원구 소재 직장 관련',
#        '금천구 소재 직장 관련', '도봉구 소재 직장 관련', '대전 IM선교회 관련', '성북구 소재 사우나 관련',
#        '강동구 소재 한방병원 관련', "성동구 소재 병원 관련(\\'21.1월)", '도봉구 소재 교회 관련',
#        '동대문구 소재 직장 관련', '광진구 소재 음식점 관련', '기타 확진자 접촉(동작구 소재 병원 관련)',
#        '중구 소재 콜센터4 관련', '동대문구 소재 고시텔 관련', '종로구 소재 직장2 관련',
#        '관악구 소재 의료기관 관련', '도축 및 육류가공업 관련', '용산구 소재 지인 모임 관련',
#        '도봉구 소재 직장2 관련', '금천구 소재 보험회사 관련', '강북구 소재 사우나 관련',
#        '중랑구 소재 아동관련 시설', '서대문구 소재 운동시설 관련', '구로구 소재 교정시설 관련',
#        '동대문구 소재 공공기관 관련', '동대문구 소재 병원 관련', '은평구 소재 요양시설 관련',
#        '노원구 소재 어린이집 관련', '수도권 가족모임 관련', '동작구 소재 병원 관련', '중구 제조업 공장2 관련',
#        '강동구 소재 사우나 관련', '강남구 문화교습소 관련', '구로구 소재 요양시설 관련', '송파구 가족 관련',
#        '성북구 소재 체육시설 관련', '구로구 소재 체육시설 관련', '용산구 소재 병원 관련', '송파구 소재 학원 관련',
#        '관악구 지인, 직장 관련', '타시도 소재 플라스틱공장 관련', '구로구 소재 직장 관련',
#        '마포구 소재 직장 관련', '용산구 직장/지인 관련', "영등포구 소재 의료기관 관련(\\'21.2월)",
#        '성북구 가족 모임 관련', '양천구 소재 유치원/어린이집 관련', '광진구 소재 어린이집 관련',
#        '종로구 소재 산후조리원 관련', "동작구 가족관련(\\'21.2월)", '성동구 소재 직장 관련',
#        '양천구 가족, 직장 관련', "중구 소재 직장 관련(\\'21.2월)", "강남구 소재 직장 관련(\\'21.2월)",
#        '중랑구 소재 요양시설 관련', "서초구 소재 의료기관 관련(\\'21.2월)", '구로구 소재 의료기관 관련',
#        "중구 상가 관련(\\'21.2월)", '서대문구 소재 직장 관련', '송파구 소재 실내체육시설 관련',
#        "금천구 소재 직장 관련(\\'21.2월)", '노원구 소재 장애인시설 관련',
#        "수도권 지인모임 관련(\\'21.2월)", "송파구 소재 요양병원 관련(\\'21.2월)",
#        '동대문구 소재 아동시설 관련', '광진구 지인모임 관련', '영등포구 소재 음식점 관련',
#        '은평구 소재 아동시설 관련', '노원구 소재 어린이집 관련(`21.2월)', '동대문구 가족/어린이집 관련',
#        '서초구 소재 빌딩관련', "동대문구 소재 병원 관련(\\'21.2.)",
#        "성북구 소재 사우나 관련(\\'21.2월)", '은평구 소재 사우나 관련', '노원구 소재 음식점 관련',
#        '은평구 소재 학원 관련', '서초구 소재 직장 관련', '서대문구 소재 방문요양시설 관련',
#        "종로구 소재 요양시설 관련(\\'21.3.)", '동대문구 소재 요양병원 관련', '강서구 소재 회사 관련',
#        '중구 지인모임 관련', '관악구 소재 미용업 관련', '수도권 지인모임 관련(`21.3월)',
#        '중구 소재 직장 관련(`21.3.)', '영등포구 소재 사우나 관련', '성동구 소재 직장 관련(`21.3월)',
#        '강동구 소재 고등학교 관련', '도봉구 소재 어린이집 관련(`21.3.)', '광진구 가족모임 관련',
#        "수도권 지인모임 관련(\\'21.3월(2))", '타시도 축산물공판장 관련',
#        '성동구 소재 직장 관련(`21.3-Ⅱ)', '성동구 소재 종교시설 관련', '강북구 소재 제조업공장 관련',
#        '광진구 소재 가족, 어린이집 관련', '도봉구 소재 아동시설 관련', '성동구 소재 직장, 종교시설 관련',
#        "강동구 소재 한방병원 관련(\\'21.3월)", '역조실 일보 반영', '은평구 소재 직장 관련',
#        '동대문구 소재 아동시설관련', "송파구 소재 병원(\\'21.3.) 관련", '영등포구 소재 직장 관련'],
#       dtype=object)

# %%
covid['현재상태'].unique()
# Out:
# array(['퇴원', '사망', nan], dtype=object)

# %% [markdown]
# # 확진일 확진자수 정보 조회

# %% [markdown]
# ## 확진일의 빈도수

# %%
covid.groupby('확진일')['확진일'].count()
# Out:
# 확진일
# 2020-01-24      1
# 2020-01-30      3
# 2020-01-31      3
# 2020-02-02      1
# 2020-02-05      2
#              ...
# 2021-03-10    137
# 2021-03-11    140
# 2021-03-12    140
# 2021-03-13    112
# 2021-03-14    112
# Name: 확진일, Length: 384, dtype: int64

# %% [markdown]
# > ### datetime으로 변환
# > - `pd.to_datetime(변환할 Series)`
# > - x 또는 y 축이 날짜 일 경우 datetime 타입으로 처리하는 것이 좋다.
# > - datetime을 변환하면 날짜만의 기능을 다룰 수 있다.
# >     - dt accessor를 이용해 datetime의 속성값들을(년, 월, 일 등) 추출할 수 있다.
# >     - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html

# %% [markdown]
# ## 확진일을 datetime으로 변환

# %%
covid['확진일'] = pd.to_datetime(covid['확진일'], format='%Y-%m-%d')

# %%
covid.head()
# Out:
#           확진일  자치구  여행력        접촉력 현재상태
# ID
# 1  2020-01-24  강서구   중국       해외유입   퇴원
# 2  2020-01-30  강서구   중국       해외유입   퇴원
# 3  2020-01-30  중랑구  NaN   종로구 집단발병   퇴원
# 4  2020-01-30  종로구   중국       해외유입   퇴원
# 5  2020-01-31  마포구  NaN  기타 확진자 접촉   퇴원

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30061 entries, 1 to 30061
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   확진일     30061 non-null  datetime64[ns]
#  1   자치구     30061 non-null  object
#  2   여행력     976 non-null    object
#  3   접촉력     30061 non-null  object
#  4   현재상태    27143 non-null  object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ## 확진일 관련 파생변수 추가
# - 확진일에서 년을 추출해서 **'년'** 컬럼을 생성
# - 확진일에서 월을 추출해서 **'월'** 컬럼을 생성
# - 확진일에서 주(1년 중 몇번째 주)를 추출해서 **'주'** 컬럼을 생성
# - 확진일에서 요일을 추출해서 **'요일'** 컬럼을 생성.

# %%
covid['년'] = covid['확진일'].dt.year
covid['월'] = covid['확진일'].dt.month
covid['주'] = covid['확진일'].dt.isocalendar().week
covid['요일'] = covid['확진일'].dt.dayofweek

# %% [markdown]
# ## 요일 정수를 문자열(월,화,수,목,금,토,일)로 변경
# - datetime에서 요일을 추출하면 정수로 반환된다.
#     - dt.week 로 조회시 - 월요일: 0, 일요일: 6
#     - dt.isocalendar()['week']로 조회시 - 월요일 : 1, 일요일: 7

# %%
def changedays(x):
    if x == 0:
        return '월'
    elif x == 1:
        return '화'
    elif x == 2:
        return '수'
    elif x == 3:
        return '목'
    elif x == 4:
        return '금'
    elif x == 5:
        return '토'
    elif x == 6:
        return '일'

covid['요일'] = covid['요일'].apply(changedays)

# %%
covid.head()
# Out:
#           확진일  자치구  여행력        접촉력 현재상태     년  월  주 요일
# ID
# 1  2020-01-24  강서구   중국       해외유입   퇴원  2020  1  4  금
# 2  2020-01-30  강서구   중국       해외유입   퇴원  2020  1  5  목
# 3  2020-01-30  중랑구  NaN   종로구 집단발병   퇴원  2020  1  5  목
# 4  2020-01-30  종로구   중국       해외유입   퇴원  2020  1  5  목
# 5  2020-01-31  마포구  NaN  기타 확진자 접촉   퇴원  2020  1  5  금

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30061 entries, 1 to 30061
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   확진일     30061 non-null  datetime64[ns]
#  1   자치구     30061 non-null  object
#  2   여행력     976 non-null    object
#  3   접촉력     30061 non-null  object
#  4   현재상태    27143 non-null  object
#  5   년       30061 non-null  int64
#  6   월       30061 non-null  int64
#  7   주       30061 non-null  UInt32
#  8   요일      30061 non-null  object
# dtypes: UInt32(1), datetime64[ns](1), int64(2), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# ###  Categorical Data 타입
# > - 범주형 타입
# > - 문자열과 차이점
# >     - 내부적으로 정수로 관리되기 때문에 메모리를 절약 할 수 있다.
# >     - 사전적 순서와 논리적 순서가 다를 경우 논리적 순서로 정렬되도록 정의 할 수 있다.
# >         - 사전적순서: Four One Three Two
# >         - 논리적순서: One Two Three Four
# > - str 타입 Series를 Categorical 타입으로 변환
# >     - `pandas.categorical(변환할Series, [categories=[고유값 리스트], ordered=None])`
#     - categories: 고유값 리스트를 지정한다. 생략할 경우 Series의 고유값들을 가지고 만든다.
#         - 원하는 순서대로 지정하기 위해서는 설정한다.
#     - ordered: 순성형 여부 설정

# %% [markdown]
# ## 요일을 Categorical Type으로 변환

# %%
covid['요일'] = pd.Categorical(covid['요일'], categories=['월','화','수','목','금','토','일'], ordered=True)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30061 entries, 1 to 30061
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   확진일     30061 non-null  datetime64[ns]
#  1   자치구     30061 non-null  object
#  2   여행력     976 non-null    object
#  3   접촉력     30061 non-null  object
#  4   현재상태    27143 non-null  object
#  5   년       30061 non-null  int64
#  6   월       30061 non-null  int64
#  7   주       30061 non-null  UInt32
#  8   요일      30061 non-null  category
# dtypes: UInt32(1), category(1), datetime64[ns](1), int64(2), object(4)
# memory usage: 2.0+ MB

# %%
covid.head()
# Out:
#           확진일  자치구  여행력        접촉력 현재상태     년  월  주 요일
# ID
# 1  2020-01-24  강서구   중국       해외유입   퇴원  2020  1  4  금
# 2  2020-01-30  강서구   중국       해외유입   퇴원  2020  1  5  목
# 3  2020-01-30  중랑구  NaN   종로구 집단발병   퇴원  2020  1  5  목
# 4  2020-01-30  종로구   중국       해외유입   퇴원  2020  1  5  목
# 5  2020-01-31  마포구  NaN  기타 확진자 접촉   퇴원  2020  1  5  금

# %% [markdown]
# ## 확진자 수 변화 추이 시각화

# %%
plt.figure(figsize=(10,7))
covid.groupby('확진일')['확진일'].count().plot(kind='line')

plt.show()

# %%
# Out:
# 'c:\\users\\mein0\\1.jupyternotecodes\\5.시각화(visualization)\\corona19_seoul\\venv\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %% [markdown]
# ## 2020년 12월 이후 확진일 기준으로 확진자 수 변화 추이 시각화

# %%
covid[covid['확진일']>='20201201']
# Out:
#              확진일   자치구  여행력                     접촉력 현재상태     년   월   주 요일
# ID
# 8201  2020-12-01   중랑구  NaN              영등포구 회사 관련   퇴원  2020  12  49  화
# 8328  2020-12-01  서대문구  NaN              영등포구 회사 관련   퇴원  2020  12  49  화
# 8604  2020-12-01   중랑구  NaN              영등포구 회사 관련   퇴원  2020  12  49  화
# 8609  2020-12-01   동작구  NaN              영등포구 회사 관련   퇴원  2020  12  49  화
# 8630  2020-12-01   강서구  NaN              영등포구 회사 관련   퇴원  2020  12  49  화
# ...          ...   ...  ...                     ...  ...   ...  ..  .. ..
# 30057 2021-03-14  서대문구  NaN              타시도 확진자 접촉  NaN  2021   3  10  일
# 30058 2021-03-14   마포구  NaN                감염경로 조사중  NaN  2021   3  10  일
# 30059 2021-03-14   타시도  NaN           관악구 소재 미용업 관련  NaN  2021   3  10  일
# 30060 2021-03-14   강동구  NaN                감염경로 조사중  NaN  2021   3  10  일
# 30061 2021-03-14  동대문구  NaN  동대문구 소재 병원 관련(\'21.2.)   사망  2021   3  10  일
#
# [21100 rows x 9 columns]

# %%
plt.figure(figsize=(10,7))
covid[covid['확진일']>='20201201'].groupby('확진일')['확진일'].count().plot(kind='line')
plt.show()

# %% [markdown]
# ## 년도-주 단위 확진자 수 변화 추이 시각화
# - ex) 2020년 1주차, 2020년 2주차 ...

# %%
plt.figure(figsize=(10,7))
covid.groupby(['년','주'])['확진일'].count().plot(kind='line')
plt.xticks(rotation=45)
plt.show()

# %%
covid.groupby(['년','주']).count()
# Out:
#           확진일   자치구  여행력   접촉력  현재상태     월    요일
# 년    주
# 2020 4      1     1    1     1     1     1     1
#      5      7     7    3     7     7     7     7
#      6      4     4    3     4     4     4     4
#      7      2     2    0     2     2     2     2
#      8     17    17    1    17    17    17    17
# ...       ...   ...  ...   ...   ...   ...   ...
# 2021 7   1149  1149   44  1149  1027  1149  1149
#      8    848   848   37   848   570   848   848
#      9    854   854   21   854   264   854   854
#      10   882   882   15   882    12   882   882
#      53   769   769   12   769   710   769   769
#
# [61 rows x 7 columns]

# %% [markdown]
# ## 년-월 단위  확진자수 조회 및 시각화

# %%
plt.figure(figsize=(10,7))
covid.groupby(['년','월'])['확진일'].count().plot(kind='line')
#plt.xticks(covid['월'].unique())
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-fc84b47d6ea0> in <module>
# ----> 1 covid[['년','월']].unique()
#       2
#       3
#
# c:\users\mein0\1.jupyternotecodes\5.시각화(visualization)\corona19_seoul\venv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %% [markdown]
# ## 월-요일별 확진자수 조회 및 시각화

# %%
plt.figure(figsize=(10,7))
covid.groupby(['월','요일'])['확진일'].count().plot(kind='line')


plt.show()

# %% [markdown]
# # 누적 확진자수 조회 및 변화 흐름 시각화
# - Series/DataFrame.cumsum()
#     - 누적 합계
# - Series.to_frame()
#     - Series를 DataFrame으로 변환

# %% [markdown]
# ## 일별 누적 확진자수 조회

# %%
covid.groupby('확진일')['요일'].count().cumsum()
# Out:
# 확진일
# 2020-01-24        1
# 2020-01-30        4
# 2020-01-31        7
# 2020-02-02        8
# 2020-02-05       10
#               ...
# 2021-03-10    29557
# 2021-03-11    29697
# 2021-03-12    29837
# 2021-03-13    29949
# 2021-03-14    30061
# Name: 요일, Length: 384, dtype: int64

# %% [markdown]
# ## 누적확진자수 파생변수 생성

# %% [markdown]
# ## 누적 확진자수 선그래프

# %%
plt.figure(figsize=(10,7))
covid.groupby('확진일')['요일'].count().cumsum().plot(kind='line')
plt.show()

# %% [markdown]
# # 자치구 기준 확진자 조회

# %%
covid['자치구'].count()
# Out:
# 30061

# %% [markdown]
# ## 자치구별 확진자수 조회

# %%
covid.groupby('자치구').count()
covid.head()
# Out:
#           확진일  자치구  여행력        접촉력 현재상태     년  월  주 요일
# ID
# 1  2020-01-24  강서구   중국       해외유입   퇴원  2020  1  4  금
# 2  2020-01-30  강서구   중국       해외유입   퇴원  2020  1  5  목
# 3  2020-01-30  중랑구  NaN   종로구 집단발병   퇴원  2020  1  5  목
# 4  2020-01-30  종로구   중국       해외유입   퇴원  2020  1  5  목
# 5  2020-01-31  마포구  NaN  기타 확진자 접촉   퇴원  2020  1  5  금

# %%
gu_count = covid.sort_values('자치구').groupby('자치구').count()
gu_count['확진일']
# Out:
# 자치구
# 강남구     1376
# 강동구     1036
# 강북구      785
# 강서구     1704
# 관악구     1408
# 광진구      876
# 구로구     1094
# 금천구      478
# 기타      2000
# 노원구     1322
# 도봉구      954
# 동대문구    1087
# 동작구     1238
# 마포구      990
# 서대문구     786
# 서초구     1148
# 성동구      763
# 성북구     1298
# 송파구     1658
# 양천구     1144
# 영등포구    1122
# 용산구      815
# 은평구     1262
# 종로구      579
# 중구       475
# 중랑구     1250
# 타시도     1413
# Name: 확진일, dtype: int64

# %% [markdown]
# ## 자치구별 확진자수 시각화

# %%
plt.figure(figsize=(10,7))
gu_count['확진일'].plot(kind='bar')
for idx, value in enumerate(gu_count['확진일']):
    plt.text(idx-0.3, value, value)
plt.show()

# %% [markdown]
# # 접촉력 관련 확진자 조회

# %%
contact = covid.groupby('접촉력').count()
contact
# Out:
#                      확진일  자치구  여행력  현재상태    년    월    주   요일
# 접촉력
# (인천계양구일가족관련) 연세나로학원    3    3    0     3    3    3    3    3
# 8.15서울도심집회           126  126    0   126  126  126  126  126
# 9월 송파구 지인모임            4    4    0     4    4    4    4    4
# Ace 손해보험              98   98    0    98   98   98   98   98
# EZHLD                  6    6    0     6    6    6    6    6
# ...                  ...  ...  ...   ...  ...  ...  ...  ...
# 플링크(IT기업)              7    7    0     7    7    7    7    7
# 한양대병원                  2    2    0     2    2    2    2    2
# 해외유입                 965  965  958   879  965  965  965  965
# 현대카드 관악구 왕성교회          2    2    0     2    2    2    2    2
# 현대커머셜                  8    8    0     8    8    8    8    8
#
# [512 rows x 8 columns]

# %% [markdown]
# ## 가장 많은 집단 감염자를 낸 접촉력 상위 15개 조회

# %%
contact.sort_values('확진일', ascending=False)['확진일'].head(15)
# Out:
# 접촉력
# 기타 확진자 접촉             9660
# 감염경로 조사중              6994
# 타시도 확진자 접촉            1304
# 동부구치소 관련              1175
# 해외유입                   965
# 성북구 사랑제일교회 관련          641
# 강서구 교회 관련              246
# 종로구 소재 파고다타운 관련        227
# 구로구 소재 요양병원/요양원 관련     226
# 강서구 댄스교습관련 시설          224
# 용산구 소재 병원 관련           219
# 병원 및 요양시설              170
# 이태원 클럽 관련              139
# 8.15서울도심집회             126
# 마포구 홍대새교회 관련           109
# Name: 확진일, dtype: int64

# %% [markdown]
# ## 가장 많은 집단 감염자를 낸 접촉력 하위 15

# %%
contact.sort_values('확진일', ascending=False)['확진일'].tail(15)
# Out:
# 접촉력
# 영등포 소재 의료기관 관련      1
# 역조실 일보 반영           1
# 안양 목회자 관련           1
# 아산병원                1
# 신 천 지               1
# 서초구 LG 유플러스         1
# 광진구 소재 병원 관련        1
# 중구 소재 콜센터(다은컨설팅)    1
# 삼성물산                1
# 동대문구 소재 아동시설관련      1
# 이에스에스콤글로벌           1
# 중랑구 서울의료원           1
# 남부교도소 관련            1
# 구로구소재 고등학교 관련       1
# 부산시 방문주사 관련         1
# Name: 확진일, dtype: int64

# %% [markdown]
# ## 접촉력 상위 15개만 시각화

# %%
plt.figure(figsize=(10,7))
contact.sort_values('확진일', ascending=False)['확진일'].head(15).plot.bar()
for idx, value in enumerate(contact.sort_values('확진일', ascending=False)['확진일'].head(15)):
    plt.text(idx-0.3, value, value)
plt.show()

# %% [markdown]
# ## 확진자를 가장 많이 발생시킨 접촉력 상위 15개를 기준으로  월별 빈도수를 집계
# - 몇 월에 발생했는지 확인 (년도는 무시)

# %%
# Out:
#       확진일  자치구  여행력  현재상태  년  주  요일
# 월
# 109     1    1    1     1  1  1   1
# 126     1    1    1     1  1  1   1
# 139     1    1    1     1  1  1   1
# 170     1    1    1     1  1  1   1
# 219     1    1    1     1  1  1   1
# 224     1    1    1     1  1  1   1
# 226     1    1    1     1  1  1   1
# 227     1    1    1     1  1  1   1
# 246     1    1    1     1  1  1   1
# 641     1    1    1     1  1  1   1
# 965     1    1    1     1  1  1   1
# 1175    1    1    1     1  1  1   1
# 1304    1    1    1     1  1  1   1
# 6994    1    1    1     1  1  1   1
# 9660    1    1    1     1  1  1   1

# %% [markdown]
# # 현재상태 관련조회

# %% [markdown]
# ## 사망자 수/비율 조회

# %% [markdown]
# ## 퇴원, 사망자, 치료중(NA)의 비율을 시각화
